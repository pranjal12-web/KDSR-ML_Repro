# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import os
os.chdir('/content/gdrive/MyDrive/KDSR-GAN')

# %%
# %cd /content/gdrive/MyDrive/KDSR-GAN
# Out:
# /content

# %%
# !pip install basicsr
# !pip install pandas
# !pip install -r requirements.txt
# !sudo python3 setup.py develop
# Out:
# Collecting basicsr
#   Downloading basicsr-1.4.2.tar.gz (172 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 172.5/172.5 kB 1.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting addict (from basicsr)
#   Downloading addict-2.4.0-py3-none-any.whl (3.8 kB)
# Requirement already satisfied: future in /usr/local/lib/python3.10/dist-packages (from basicsr) (0.18.3)
# Collecting lmdb (from basicsr)
#   Downloading lmdb-1.4.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (299 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 299.2/299.2 kB 6.1 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from basicsr) (1.23.5)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.10/dist-packages (from basicsr) (4.8.0.76)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from basicsr) (9.4.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from basicsr) (6.0.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from basicsr) (2.31.0)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.10/dist-packages (from basicsr) (0.19.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from basicsr) (1.11.4)
# Collecting tb-nightly (from basicsr)
#   Downloading tb_nightly-2.16.0a20240202-py3-none-any.whl (5.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 36.2 MB/s eta 0:00:00
# Requirement already satisfied: torch>=1.7 in /usr/local/lib/python3.10/dist-packages (from basicsr) (2.1.0+cu121)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from basicsr) (0.16.0+cu121)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from basicsr) (4.66.1)
# Collecting yapf (from basicsr)
#   Downloading yapf-0.40.2-py3-none-any.whl (254 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 254.7/254.7 kB 27.2 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->basicsr) (3.13.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->basicsr) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->basicsr) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->basicsr) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->basicsr) (3.1.3)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->basicsr) (2023.6.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->basicsr) (2.1.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->basicsr) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->basicsr) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->basicsr) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->basicsr) (2023.11.17)
# Requirement already satisfied: imageio>=2.4.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image->basicsr) (2.31.6)
# Requirement already satisfied: tifffile>=2019.7.26 in /usr/local/lib/python3.10/dist-packages (from scikit-image->basicsr) (2024.1.30)
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image->basicsr) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from scikit-image->basicsr) (23.2)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.10/dist-packages (from tb-nightly->basicsr) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.10/dist-packages (from tb-nightly->basicsr) (1.60.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tb-nightly->basicsr) (3.5.2)
# Requirement already satisfied: protobuf>=3.19.6 in /usr/local/lib/python3.10/dist-packages (from tb-nightly->basicsr) (3.20.3)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.10/dist-packages (from tb-nightly->basicsr) (67.7.2)
# Requirement already satisfied: six>1.9 in /usr/local/lib/python3.10/dist-packages (from tb-nightly->basicsr) (1.16.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tb-nightly->basicsr) (0.7.2)
# Collecting tf-keras-nightly (from tb-nightly->basicsr)
#   Downloading tf_keras_nightly-2.16.0.dev2024020210-py3-none-any.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 76.7 MB/s eta 0:00:00
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tb-nightly->basicsr) (3.0.1)
# Requirement already satisfied: importlib-metadata>=6.6.0 in /usr/local/lib/python3.10/dist-packages (from yapf->basicsr) (7.0.1)
# Requirement already satisfied: platformdirs>=3.5.1 in /usr/local/lib/python3.10/dist-packages (from yapf->basicsr) (4.2.0)
# Requirement already satisfied: tomli>=2.0.1 in /usr/local/lib/python3.10/dist-packages (from yapf->basicsr) (2.0.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata>=6.6.0->yapf->basicsr) (3.17.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tb-nightly->basicsr) (2.1.4)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.7->basicsr) (1.3.0)
# Building wheels for collected packages: basicsr
#   Building wheel for basicsr (setup.py) ... done
#   Created wheel for basicsr: filename=basicsr-1.4.2-py3-none-any.whl size=214818 sha256=98482f9f1479eb0af2f833a89596b67ad0c671de961c98b34bf3805c8bb13120
#   Stored in directory: /root/.cache/pip/wheels/38/83/99/2d8437cc652a01af27df5ff037a4075e95b52d67705c5f30ca
# Successfully built basicsr
# Installing collected packages: lmdb, addict, tf-keras-nightly, yapf, tb-nightly, basicsr
# Successfully installed addict-2.4.0 basicsr-1.4.2 lmdb-1.4.1 tb-nightly-2.16.0a20240202 tf-keras-nightly-2.16.0.dev2024020210 yapf-0.40.2
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (1.5.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2023.4)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.23.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Requirement already satisfied: basicsr>=1.3.3.11 in /usr/local/lib/python3.10/dist-packages (from -r requirements.txt (line 1)) (1.4.2)
# Collecting facexlib>=0.2.0.3 (from -r requirements.txt (line 2))
#   Downloading facexlib-0.3.0-py3-none-any.whl (59 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.6/59.6 kB 900.3 kB/s eta 0:00:00
# Collecting gfpgan>=0.2.1 (from -r requirements.txt (line 3))
#   Downloading gfpgan-1.3.8-py3-none-any.whl (52 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.2/52.2 kB 3.2 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from -r requirements.txt (line 4)) (1.23.5)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.10/dist-packages (from -r requirements.txt (line 5)) (4.8.0.76)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from -r requirements.txt (line 6)) (9.4.0)
# Requirement already satisfied: torch>=1.7 in /usr/local/lib/python3.10/dist-packages (from -r requirements.txt (line 7)) (2.1.0+cu121)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from -r requirements.txt (line 8)) (0.16.0+cu121)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from -r requirements.txt (line 9)) (4.66.1)
# Requirement already satisfied: addict in /usr/local/lib/python3.10/dist-packages (from basicsr>=1.3.3.11->-r requirements.txt (line 1)) (2.4.0)
# Requirement already satisfied: future in /usr/local/lib/python3.10/dist-packages (from basicsr>=1.3.3.11->-r requirements.txt (line 1)) (0.18.3)
# Requirement already satisfied: lmdb in /usr/local/lib/python3.10/dist-packages (from basicsr>=1.3.3.11->-r requirements.txt (line 1)) (1.4.1)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from basicsr>=1.3.3.11->-r requirements.txt (line 1)) (6.0.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from basicsr>=1.3.3.11->-r requirements.txt (line 1)) (2.31.0)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.10/dist-packages (from basicsr>=1.3.3.11->-r requirements.txt (line 1)) (0.19.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from basicsr>=1.3.3.11->-r requirements.txt (line 1)) (1.11.4)
# Requirement already satisfied: tb-nightly in /usr/local/lib/python3.10/dist-packages (from basicsr>=1.3.3.11->-r requirements.txt (line 1)) (2.16.0a20240202)
# Requirement already satisfied: yapf in /usr/local/lib/python3.10/dist-packages (from basicsr>=1.3.3.11->-r requirements.txt (line 1)) (0.40.2)
# Collecting filterpy (from facexlib>=0.2.0.3->-r requirements.txt (line 2))
#   Downloading filterpy-1.4.5.zip (177 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.0/178.0 kB 3.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numba in /usr/local/lib/python3.10/dist-packages (from facexlib>=0.2.0.3->-r requirements.txt (line 2)) (0.58.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->-r requirements.txt (line 7)) (3.13.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->-r requirements.txt (line 7)) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->-r requirements.txt (line 7)) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->-r requirements.txt (line 7)) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->-r requirements.txt (line 7)) (3.1.3)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->-r requirements.txt (line 7)) (2023.6.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->-r requirements.txt (line 7)) (2.1.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from filterpy->facexlib>=0.2.0.3->-r requirements.txt (line 2)) (3.7.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.7->-r requirements.txt (line 7)) (2.1.4)
# Requirement already satisfied: llvmlite<0.42,>=0.41.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba->facexlib>=0.2.0.3->-r requirements.txt (line 2)) (0.41.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->basicsr>=1.3.3.11->-r requirements.txt (line 1)) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->basicsr>=1.3.3.11->-r requirements.txt (line 1)) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->basicsr>=1.3.3.11->-r requirements.txt (line 1)) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->basicsr>=1.3.3.11->-r requirements.txt (line 1)) (2023.11.17)
# Requirement already satisfied: imageio>=2.4.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image->basicsr>=1.3.3.11->-r requirements.txt (line 1)) (2.31.6)
# Requirement already satisfied: tifffile>=2019.7.26 in /usr/local/lib/python3.10/dist-packages (from scikit-image->basicsr>=1.3.3.11->-r requirements.txt (line 1)) (2024.1.30)
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image->basicsr>=1.3.3.11->-r requirements.txt (line 1)) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from scikit-image->basicsr>=1.3.3.11->-r requirements.txt (line 1)) (23.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.7->-r requirements.txt (line 7)) (1.3.0)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.10/dist-packages (from tb-nightly->basicsr>=1.3.3.11->-r requirements.txt (line 1)) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.10/dist-packages (from tb-nightly->basicsr>=1.3.3.11->-r requirements.txt (line 1)) (1.60.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tb-nightly->basicsr>=1.3.3.11->-r requirements.txt (line 1)) (3.5.2)
# Requirement already satisfied: protobuf>=3.19.6 in /usr/local/lib/python3.10/dist-packages (from tb-nightly->basicsr>=1.3.3.11->-r requirements.txt (line 1)) (3.20.3)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.10/dist-packages (from tb-nightly->basicsr>=1.3.3.11->-r requirements.txt (line 1)) (67.7.2)
# Requirement already satisfied: six>1.9 in /usr/local/lib/python3.10/dist-packages (from tb-nightly->basicsr>=1.3.3.11->-r requirements.txt (line 1)) (1.16.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tb-nightly->basicsr>=1.3.3.11->-r requirements.txt (line 1)) (0.7.2)
# Requirement already satisfied: tf-keras-nightly in /usr/local/lib/python3.10/dist-packages (from tb-nightly->basicsr>=1.3.3.11->-r requirements.txt (line 1)) (2.16.0.dev2024020210)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tb-nightly->basicsr>=1.3.3.11->-r requirements.txt (line 1)) (3.0.1)
# Requirement already satisfied: importlib-metadata>=6.6.0 in /usr/local/lib/python3.10/dist-packages (from yapf->basicsr>=1.3.3.11->-r requirements.txt (line 1)) (7.0.1)
# Requirement already satisfied: platformdirs>=3.5.1 in /usr/local/lib/python3.10/dist-packages (from yapf->basicsr>=1.3.3.11->-r requirements.txt (line 1)) (4.2.0)
# Requirement already satisfied: tomli>=2.0.1 in /usr/local/lib/python3.10/dist-packages (from yapf->basicsr>=1.3.3.11->-r requirements.txt (line 1)) (2.0.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata>=6.6.0->yapf->basicsr>=1.3.3.11->-r requirements.txt (line 1)) (3.17.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->filterpy->facexlib>=0.2.0.3->-r requirements.txt (line 2)) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->filterpy->facexlib>=0.2.0.3->-r requirements.txt (line 2)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->filterpy->facexlib>=0.2.0.3->-r requirements.txt (line 2)) (4.47.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->filterpy->facexlib>=0.2.0.3->-r requirements.txt (line 2)) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->filterpy->facexlib>=0.2.0.3->-r requirements.txt (line 2)) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->filterpy->facexlib>=0.2.0.3->-r requirements.txt (line 2)) (2.8.2)
# Building wheels for collected packages: filterpy
#   Building wheel for filterpy (setup.py) ... done
#   Created wheel for filterpy: filename=filterpy-1.4.5-py3-none-any.whl size=110458 sha256=c9e1eb9ce9c297a1cb25ef59d86d19a1718a676c39bf8e6bf1a76690bb4c4410
#   Stored in directory: /root/.cache/pip/wheels/0f/0c/ea/218f266af4ad626897562199fbbcba521b8497303200186102
# Successfully built filterpy
# Installing collected packages: filterpy, facexlib, gfpgan
# Successfully installed facexlib-0.3.0 filterpy-1.4.5 gfpgan-1.3.8
# /usr/local/lib/python3.10/dist-packages/setuptools/__init__.py:84: _DeprecatedInstaller: setuptools.installer and fetch_build_eggs are deprecated.
# !!
#
#         ********************************************************************************
#         Requirements should be satisfied by a PEP 517 installer.
#         If you are using pip, you can try `pip install --use-pep517`.
#         ********************************************************************************
#
# !!
#   dist.fetch_build_eggs(dist.setup_requires)
# running develop
# /usr/local/lib/python3.10/dist-packages/setuptools/command/develop.py:40: EasyInstallDeprecationWarning: easy_install command is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` and ``easy_install``.
#         Instead, use pypa/build, pypa/installer, pypa/build or
#         other standards-based tools.
#
#         See https://github.com/pypa/setuptools/issues/917 for details.
#         ********************************************************************************
#
# !!
#   easy_install.initialize_options(self)
# /usr/local/lib/python3.10/dist-packages/setuptools/_distutils/cmd.py:66: SetuptoolsDeprecationWarning: setup.py install is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` directly.
#         Instead, use pypa/build, pypa/installer, pypa/build or
#         other standards-based tools.
#
#         See https://blog.ganssle.io/articles/2021/10/setup-py-deprecated.html for details.
#         ********************************************************************************
#
# !!
#   self.initialize_options()
# running egg_info
# writing realesrgan.egg-info/PKG-INFO
# writing dependency_links to realesrgan.egg-info/dependency_links.txt
# writing requirements to realesrgan.egg-info/requires.txt
# writing top-level names to realesrgan.egg-info/top_level.txt
# reading manifest file 'realesrgan.egg-info/SOURCES.txt'
# writing manifest file 'realesrgan.egg-info/SOURCES.txt'
# running build_ext
# Creating /usr/local/lib/python3.10/dist-packages/realesrgan.egg-link (link to .)
# Adding realesrgan 0.2.5.0 to easy-install.pth file
#
# Installed /content/gdrive/MyDrive/KDSR-GAN
# Processing dependencies for realesrgan==0.2.5.0
# Searching for tqdm==4.66.1
# Best match: tqdm 4.66.1
# Adding tqdm 4.66.1 to easy-install.pth file
# Installing tqdm script to /usr/local/bin
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for torchvision==0.16.0+cu121
# Best match: torchvision 0.16.0+cu121
# Adding torchvision 0.16.0+cu121 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for torch==2.1.0+cu121
# Best match: torch 2.1.0+cu121
# Adding torch 2.1.0+cu121 to easy-install.pth file
# Installing convert-caffe2-to-onnx script to /usr/local/bin
# Installing convert-onnx-to-caffe2 script to /usr/local/bin
# Installing torchrun script to /usr/local/bin
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for Pillow==9.4.0
# Best match: Pillow 9.4.0
# Adding Pillow 9.4.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for opencv-python==4.8.0.76
# Best match: opencv-python 4.8.0.76
# Adding opencv-python 4.8.0.76 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for numpy==1.23.5
# Best match: numpy 1.23.5
# Adding numpy 1.23.5 to easy-install.pth file
# Installing f2py script to /usr/local/bin
# Installing f2py3 script to /usr/local/bin
# Installing f2py3.10 script to /usr/local/bin
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for gfpgan==1.3.8
# Best match: gfpgan 1.3.8
# Adding gfpgan 1.3.8 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for facexlib==0.3.0
# Best match: facexlib 0.3.0
# Adding facexlib 0.3.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for basicsr==1.4.2
# Best match: basicsr 1.4.2
# Adding basicsr 1.4.2 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for requests==2.31.0
# Best match: requests 2.31.0
# Adding requests 2.31.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for triton==2.1.0
# Best match: triton 2.1.0
# Adding triton 2.1.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for fsspec==2023.6.0
# Best match: fsspec 2023.6.0
# Adding fsspec 2023.6.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for Jinja2==3.1.3
# Best match: Jinja2 3.1.3
# Adding Jinja2 3.1.3 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for networkx==3.2.1
# Best match: networkx 3.2.1
# Adding networkx 3.2.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for sympy==1.12
# Best match: sympy 1.12
# Adding sympy 1.12 to easy-install.pth file
# Installing isympy script to /usr/local/bin
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for typing-extensions==4.5.0
# Best match: typing-extensions 4.5.0
# Adding typing-extensions 4.5.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for filelock==3.13.1
# Best match: filelock 3.13.1
# Adding filelock 3.13.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for yapf==0.40.2
# Best match: yapf 0.40.2
# Adding yapf 0.40.2 to easy-install.pth file
# Installing yapf script to /usr/local/bin
# Installing yapf-diff script to /usr/local/bin
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for tb-nightly==2.16.0a20240202
# Best match: tb-nightly 2.16.0a20240202
# Adding tb-nightly 2.16.0a20240202 to easy-install.pth file
# Installing tensorboard script to /usr/local/bin
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for scipy==1.11.4
# Best match: scipy 1.11.4
# Adding scipy 1.11.4 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for PyYAML==6.0.1
# Best match: PyYAML 6.0.1
# Adding PyYAML 6.0.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for lmdb==1.4.1
# Best match: lmdb 1.4.1
# Adding lmdb 1.4.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for numba==0.58.1
# Best match: numba 0.58.1
# Adding numba 0.58.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for filterpy==1.4.5
# Best match: filterpy 1.4.5
# Adding filterpy 1.4.5 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for scikit-image==0.19.3
# Best match: scikit-image 0.19.3
# Adding scikit-image 0.19.3 to easy-install.pth file
# Installing skivi script to /usr/local/bin
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for future==0.18.3
# Best match: future 0.18.3
# Adding future 0.18.3 to easy-install.pth file
# Installing futurize script to /usr/local/bin
# Installing pasteurize script to /usr/local/bin
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for addict==2.4.0
# Best match: addict 2.4.0
# Adding addict 2.4.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for certifi==2023.11.17
# Best match: certifi 2023.11.17
# Adding certifi 2023.11.17 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for urllib3==2.0.7
# Best match: urllib3 2.0.7
# Adding urllib3 2.0.7 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for idna==3.6
# Best match: idna 3.6
# Adding idna 3.6 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for charset-normalizer==3.3.2
# Best match: charset-normalizer 3.3.2
# Adding charset-normalizer 3.3.2 to easy-install.pth file
# Installing normalizer script to /usr/local/bin
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for MarkupSafe==2.1.4
# Best match: MarkupSafe 2.1.4
# Adding MarkupSafe 2.1.4 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for mpmath==1.3.0
# Best match: mpmath 1.3.0
# Adding mpmath 1.3.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for tomli==2.0.1
# Best match: tomli 2.0.1
# Adding tomli 2.0.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for platformdirs==4.2.0
# Best match: platformdirs 4.2.0
# Adding platformdirs 4.2.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for importlib-metadata==7.0.1
# Best match: importlib-metadata 7.0.1
# Adding importlib-metadata 7.0.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for werkzeug==3.0.1
# Best match: werkzeug 3.0.1
# Adding werkzeug 3.0.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for tf-keras-nightly==2.16.0.dev2024020210
# Best match: tf-keras-nightly 2.16.0.dev2024020210
# Adding tf-keras-nightly 2.16.0.dev2024020210 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for tensorboard-data-server==0.7.2
# Best match: tensorboard-data-server 0.7.2
# Adding tensorboard-data-server 0.7.2 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for six==1.16.0
# Best match: six 1.16.0
# Adding six 1.16.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for setuptools==67.7.2
# Best match: setuptools 67.7.2
# Adding setuptools 67.7.2 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for protobuf==3.20.3
# Best match: protobuf 3.20.3
# Adding protobuf 3.20.3 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for Markdown==3.5.2
# Best match: Markdown 3.5.2
# Adding Markdown 3.5.2 to easy-install.pth file
# Installing markdown_py script to /usr/local/bin
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for grpcio==1.60.0
# Best match: grpcio 1.60.0
# Adding grpcio 1.60.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for absl-py==1.4.0
# Best match: absl-py 1.4.0
# Adding absl-py 1.4.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for llvmlite==0.41.1
# Best match: llvmlite 0.41.1
# Adding llvmlite 0.41.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for matplotlib==3.7.1
# Best match: matplotlib 3.7.1
# Adding matplotlib 3.7.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for packaging==23.2
# Best match: packaging 23.2
# Adding packaging 23.2 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for pywavelets==1.5.0
# Best match: pywavelets 1.5.0
# Adding pywavelets 1.5.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for tifffile==2024.1.30
# Best match: tifffile 2024.1.30
# Adding tifffile 2024.1.30 to easy-install.pth file
# Installing lsm2bin script to /usr/local/bin
# Installing tiff2fsspec script to /usr/local/bin
# Installing tiffcomment script to /usr/local/bin
# Installing tifffile script to /usr/local/bin
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for imageio==2.31.6
# Best match: imageio 2.31.6
# Adding imageio 2.31.6 to easy-install.pth file
# Installing imageio_download_bin script to /usr/local/bin
# Installing imageio_remove_bin script to /usr/local/bin
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for zipp==3.17.0
# Best match: zipp 3.17.0
# Adding zipp 3.17.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for python-dateutil==2.8.2
# Best match: python-dateutil 2.8.2
# Adding python-dateutil 2.8.2 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for pyparsing==3.1.1
# Best match: pyparsing 3.1.1
# Adding pyparsing 3.1.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for kiwisolver==1.4.5
# Best match: kiwisolver 1.4.5
# Adding kiwisolver 1.4.5 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for fonttools==4.47.2
# Best match: fonttools 4.47.2
# Adding fonttools 4.47.2 to easy-install.pth file
# Installing fonttools script to /usr/local/bin
# Installing pyftmerge script to /usr/local/bin
# Installing pyftsubset script to /usr/local/bin
# Installing ttx script to /usr/local/bin
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for cycler==0.12.1
# Best match: cycler 0.12.1
# Adding cycler 0.12.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for contourpy==1.2.0
# Best match: contourpy 1.2.0
# Adding contourpy 1.2.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Finished processing dependencies for realesrgan==0.2.5.0

# %%
import os
os.environ['OMP_NUM_THREADS'] = '1'

# %%
# !python3 kdsrgan/train.py -opt options/train_kdsrnet_x4TA.yml --debug
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/transforms/functional_tensor.py:5: UserWarning: The torchvision.transforms.functional_tensor module is deprecated in 0.15 and will be **removed in 0.17**. Please don't rely on it. You probably just need to use APIs in torchvision.transforms.functional or in torchvision.transforms.v2.functional.
#   warnings.warn(
# Disable distributed.
# Path already exists. Rename it to /content/gdrive/MyDrive/KDSR-GAN/experiments/debug_train_KDSRNetTAx4plus_1000k_B12G4_archived_20240203_064859
# 2024-02-03 06:48:59,828 INFO:
#                 ____                _       _____  ____
#                / __ ) ____ _ _____ (_)_____/ ___/ / __ \
#               / __  |/ __ `// ___// // ___/\__ \ / /_/ /
#              / /_/ // /_/ /(__  )/ // /__ ___/ // _, _/
#             /_____/ \__,_//____//_/ \___//____//_/ |_|
#      ______                   __   __                 __      __
#     / ____/____   ____   ____/ /  / /   __  __ _____ / /__   / /
#    / / __ / __ \ / __ \ / __  /  / /   / / / // ___// //_/  / /
#   / /_/ // /_/ // /_/ // /_/ /  / /___/ /_/ // /__ / /<    /_/
#   \____/ \____/ \____/ \____/  /_____/\____/ \___//_/|_|  (_)
#
# Version Information:
# 	BasicSR: 1.4.2
# 	PyTorch: 2.1.0+cu121
# 	TorchVision: 0.16.0+cu121
# 2024-02-03 06:48:59,829 INFO:
#   name: debug_train_KDSRNetTAx4plus_1000k_B12G4
#   model_type: KDSRNetTAModel
#   scale: 4
#   num_gpu: 1
#   manual_seed: 0
#   gt_usm: False
#   resize_prob: [0.2, 0.7, 0.1]
#   resize_range: [0.15, 1.5]
#   gaussian_noise_prob: 0.5
#   noise_range: [1, 30]
#   poisson_scale_range: [0.05, 3]
#   gray_noise_prob: 0.4
#   jpeg_range: [30, 95]
#   second_blur_prob: 0.8
#   resize_prob2: [0.3, 0.4, 0.3]
#   resize_range2: [0.3, 1.2]
#   gaussian_noise_prob2: 0.5
#   noise_range2: [1, 25]
#   poisson_scale_range2: [0.05, 2.5]
#   gray_noise_prob2: 0.4
#   jpeg_range2: [30, 95]
#   gt_size: 256
#   queue_size: 180
#   datasets:[
#     train:[
#       name: DF2K+OST
#       type: RealESRGANDataset_basicsr
#       dataroot_gt: /content/gdrive/MyDrive/KDSR-GAN/datasets/DF2K/DF2K_HR
#       meta_info: /content/gdrive/MyDrive/KDSR-GAN/datasets/DF2K/meta_info/meta_info_DF2Kmultiscale.txt
#       io_backend:[
#         type: disk
#       ]
#       blur_kernel_size: 21
#       kernel_list: ['iso', 'aniso', 'generalized_iso', 'generalized_aniso', 'plateau_iso', 'plateau_aniso']
#       kernel_prob: [0.45, 0.25, 0.12, 0.03, 0.12, 0.03]
#       sinc_prob: 0.1
#       blur_sigma: [0.2, 3]
#       betag_range: [0.5, 4]
#       betap_range: [1, 2]
#       blur_kernel_size2: 21
#       kernel_list2: ['iso', 'aniso', 'generalized_iso', 'generalized_aniso', 'plateau_iso', 'plateau_aniso']
#       kernel_prob2: [0.45, 0.25, 0.12, 0.03, 0.12, 0.03]
#       sinc_prob2: 0.1
#       blur_sigma2: [0.2, 1.5]
#       betag_range2: [0.5, 4]
#       betap_range2: [1, 2]
#       blur_kernel_size3: 21
#       blur_sigma3: 0.5
#       kernel_list3: ['gaussian', 'box', 'log', 'triangle', 'epanechnikov', 'biweight']
#       kernel_prob3: [0.1, 0.1, 0.1, 0.2, 0.2, 0.3]
#       final_sinc_prob: 0.8
#       gt_size: 256
#       use_hflip: True
#       use_rot: False
#       use_shuffle: True
#       num_worker_per_gpu: 6
#       batch_size_per_gpu: 9
#       dataset_enlarge_ratio: 1
#       prefetch_mode: None
#       phase: train
#       scale: 4
#     ]
#   ]
#   network_g:[
#     type: BlindSR_TA
#     n_feats: 128
#     n_encoder_res: 6
#     scale: 4
#     n_sr_blocks: 42
#   ]
#   path:[
#     pretrain_network_g: None
#     param_key_g: params_ema
#     strict_load_g: True
#     resume_state: None
#     experiments_root: /content/gdrive/MyDrive/KDSR-GAN/experiments/debug_train_KDSRNetTAx4plus_1000k_B12G4
#     models: /content/gdrive/MyDrive/KDSR-GAN/experiments/debug_train_KDSRNetTAx4plus_1000k_B12G4/models
#     training_states: /content/gdrive/MyDrive/KDSR-GAN/experiments/debug_train_KDSRNetTAx4plus_1000k_B12G4/training_states
#     log: /content/gdrive/MyDrive/KDSR-GAN/experiments/debug_train_KDSRNetTAx4plus_1000k_B12G4
#     visualization: /content/gdrive/MyDrive/KDSR-GAN/experiments/debug_train_KDSRNetTAx4plus_1000k_B12G4/visualization
#   ]
#   train:[
#     ema_decay: 0.999
#     optim_g:[
#       type: Adam
#       lr: 0.0001
#       weight_decay: 0
#       betas: [0.9, 0.99]
#     ]
#     scheduler:[
#       type: MultiStepLR
#       milestones: [4000000]
#       gamma: 0.5
#     ]
#     total_iter: 50
#     warmup_iter: -1
#     pixel_opt:[
#       type: L1Loss
#       loss_weight: 1.0
#       reduction: mean
#     ]
#   ]
#   logger:[
#     print_freq: 1
#     save_checkpoint_freq: 8
#     use_tb_logger: True
#     wandb:[
#       project: None
#       resume_id: None
#     ]
#   ]
#   dist_params:[
#     backend: nccl
#     port: 29500
#   ]
#   dist: False
#   rank: 0
#   world_size: 1
#   auto_resume: False
#   is_train: True
#   root_path: /content/gdrive/MyDrive/KDSR-GAN
#
# 2024-02-03 06:48:59,834 INFO: Dataset [RealESRGANDataset] - DF2K+OST is built.
# 2024-02-03 06:48:59,834 INFO: Training statistics:
# 	Number of train images: 173
# 	Dataset enlarge ratio: 1
# 	Batch size per gpu: 9
# 	World size (gpu number): 1
# 	Require iter number per epoch: 20
# 	Total epochs: 3; iters: 50.
# 2024-02-03 06:49:00,076 INFO: Network [BlindSR_TA] is created.
# 2024-02-03 06:49:00,366 INFO: Network: BlindSR_TA, with parameters: 18,901,403
# 2024-02-03 06:49:00,366 INFO: BlindSR_TA(
#   (G): KDSR(
#     (sub_mean): MeanShift(3, 3, kernel_size=(1, 1), stride=(1, 1))
#     (add_mean): MeanShift(3, 3, kernel_size=(1, 1), stride=(1, 1))
#     (head): Sequential(
#       (0): Conv2d(3, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#     (body): Sequential(
#       (0): DAG(
#         (body): Sequential(
#           (0): IDR_DCRB(
#             (da_conv1): IDR_DDC(
#               (kernel): Sequential(
#                 (0): Linear(in_features=128, out_features=128, bias=False)
#                 (1): LeakyReLU(negative_slope=0.1, inplace=True)
#                 (2): Linear(in_features=128, out_features=1152, bias=False)
#               )
#             )
#             (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (relu): LeakyReLU(negative_slope=0.1, inplace=True)
#           )
#           (1): IDR_DCRB(
#             (da_conv1): IDR_DDC(
#               (kernel): Sequential(
#                 (0): Linear(in_features=128, out_features=128, bias=False)
#                 (1): LeakyReLU(negative_slope=0.1, inplace=True)
#                 (2): Linear(in_features=128, out_features=1152, bias=False)
#               )
#             )
#             (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (relu): LeakyReLU(negative_slope=0.1, inplace=True)
#           )
#           (2): IDR_DCRB(
#             (da_conv1): IDR_DDC(
#               (kernel): Sequential(
#                 (0): Linear(in_features=128, out_features=128, bias=False)
#                 (1): LeakyReLU(negative_slope=0.1, inplace=True)
#                 (2): Linear(in_features=128, out_features=1152, bias=False)
#               )
#             )
#             (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (relu): LeakyReLU(negative_slope=0.1, inplace=True)
#           )
#           (3): IDR_DCRB(
#             (da_conv1): IDR_DDC(
#               (kernel): Sequential(
#                 (0): Linear(in_features=128, out_features=128, bias=False)
#                 (1): LeakyReLU(negative_slope=0.1, inplace=True)
#                 (2): Linear(in_features=128, out_features=1152, bias=False)
#               )
#             )
#             (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (relu): LeakyReLU(negative_slope=0.1, inplace=True)
#           )
#           (4): IDR_DCRB(
#             (da_conv1): IDR_DDC(
#               (kernel): Sequential(
#                 (0): Linear(in_features=128, out_features=128, bias=False)
#                 (1): LeakyReLU(negative_slope=0.1, inplace=True)
#                 (2): Linear(in_features=128, out_features=1152, bias=False)
#               )
#             )
#             (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (relu): LeakyReLU(negative_slope=0.1, inplace=True)
#           )
#           (5): IDR_DCRB(
#             (da_conv1): IDR_DDC(
#               (kernel): Sequential(
#                 (0): Linear(in_features=128, out_features=128, bias=False)
#                 (1): LeakyReLU(negative_slope=0.1, inplace=True)
#                 (2): Linear(in_features=128, out_features=1152, bias=False)
#               )
#             )
#             (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (relu): LeakyReLU(negative_slope=0.1, inplace=True)
#           )
#           (6): IDR_DCRB(
#             (da_conv1): IDR_DDC(
#               (kernel): Sequential(
#                 (0): Linear(in_features=128, out_features=128, bias=False)
#                 (1): LeakyReLU(negative_slope=0.1, inplace=True)
#                 (2): Linear(in_features=128, out_features=1152, bias=False)
#               )
#             )
#             (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (relu): LeakyReLU(negative_slope=0.1, inplace=True)
#           )
#           (7): IDR_DCRB(
#             (da_conv1): IDR_DDC(
#               (kernel): Sequential(
#                 (0): Linear(in_features=128, out_features=128, bias=False)
#                 (1): LeakyReLU(negative_slope=0.1, inplace=True)
#                 (2): Linear(in_features=128, out_features=1152, bias=False)
#               )
#             )
#             (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (relu): LeakyReLU(negative_slope=0.1, inplace=True)
#           )
#           (8): IDR_DCRB(
#             (da_conv1): IDR_DDC(
#               (kernel): Sequential(
#                 (0): Linear(in_features=128, out_features=128, bias=False)
#                 (1): LeakyReLU(negative_slope=0.1, inplace=True)
#                 (2): Linear(in_features=128, out_features=1152, bias=False)
#               )
#             )
#             (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (relu): LeakyReLU(negative_slope=0.1, inplace=True)
#           )
#           (9): IDR_DCRB(
#             (da_conv1): IDR_DDC(
#               (kernel): Sequential(
#                 (0): Linear(in_features=128, out_features=128, bias=False)
#                 (1): LeakyReLU(negative_slope=0.1, inplace=True)
#                 (2): Linear(in_features=128, out_features=1152, bias=False)
#               )
#             )
#             (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (relu): LeakyReLU(negative_slope=0.1, inplace=True)
#           )
#           (10): IDR_DCRB(
#             (da_conv1): IDR_DDC(
#               (kernel): Sequential(
#                 (0): Linear(in_features=128, out_features=128, bias=False)
#                 (1): LeakyReLU(negative_slope=0.1, inplace=True)
#                 (2): Linear(in_features=128, out_features=1152, bias=False)
#               )
#             )
#             (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (relu): LeakyReLU(negative_slope=0.1, inplace=True)
#           )
#           (11): IDR_DCRB(
#             (da_conv1): IDR_DDC(
#               (kernel): Sequential(
#                 (0): Linear(in_features=128, out_features=128, bias=False)
#                 (1): LeakyReLU(negative_slope=0.1, inplace=True)
#                 (2): Linear(in_features=128, out_features=1152, bias=False)
#               )
#             )
#             (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (relu): LeakyReLU(negative_slope=0.1, inplace=True)
#           )
#           (12): IDR_DCRB(
#             (da_conv1): IDR_DDC(
#               (kernel): Sequential(
#                 (0): Linear(in_features=128, out_features=128, bias=False)
#                 (1): LeakyReLU(negative_slope=0.1, inplace=True)
#                 (2): Linear(in_features=128, out_features=1152, bias=False)
#               )
#             )
#             (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (relu): LeakyReLU(negative_slope=0.1, inplace=True)
#           )
#           (13): IDR_DCRB(
#             (da_conv1): IDR_DDC(
#               (kernel): Sequential(
#                 (0): Linear(in_features=128, out_features=128, bias=False)
#                 (1): LeakyReLU(negative_slope=0.1, inplace=True)
#                 (2): Linear(in_features=128, out_features=1152, bias=False)
#               )
#             )
#             (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (relu): LeakyReLU(negative_slope=0.1, inplace=True)
#           )
#           (14): IDR_DCRB(
#             (da_conv1): IDR_DDC(
#               (kernel): Sequential(
#                 (0): Linear(in_features=128, out_features=128, bias=False)
#                 (1): LeakyReLU(negative_slope=0.1, inplace=True)
#                 (2): Linear(in_features=128, out_features=1152, bias=False)
#               )
#             )
#             (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (relu): LeakyReLU(negative_slope=0.1, inplace=True)
#           )
#           (15): IDR_DCRB(
#             (da_conv1): IDR_DDC(
#               (kernel): Sequential(
#                 (0): Linear(in_features=128, out_features=128, bias=False)
#                 (1): LeakyReLU(negative_slope=0.1, inplace=True)
#                 (2): Linear(in_features=128, out_features=1152, bias=False)
#               )
#             )
#             (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (relu): LeakyReLU(negative_slope=0.1, inplace=True)
#           )
#           (16): IDR_DCRB(
#             (da_conv1): IDR_DDC(
#               (kernel): Sequential(
#                 (0): Linear(in_features=128, out_features=128, bias=False)
#                 (1): LeakyReLU(negative_slope=0.1, inplace=True)
#                 (2): Linear(in_features=128, out_features=1152, bias=False)
#               )
#             )
#             (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (relu): LeakyReLU(negative_slope=0.1, inplace=True)
#           )
#           (17): IDR_DCRB(
#             (da_conv1): IDR_DDC(
#               (kernel): Sequential(
#                 (0): Linear(in_features=128, out_features=128, bias=False)
#                 (1): LeakyReLU(negative_slope=0.1, inplace=True)
#                 (2): Linear(in_features=128, out_features=1152, bias=False)
#               )
#             )
#             (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (relu): LeakyReLU(negative_slope=0.1, inplace=True)
#           )
#           (18): IDR_DCRB(
#             (da_conv1): IDR_DDC(
#               (kernel): Sequential(
#                 (0): Linear(in_features=128, out_features=128, bias=False)
#                 (1): LeakyReLU(negative_slope=0.1, inplace=True)
#                 (2): Linear(in_features=128, out_features=1152, bias=False)
#               )
#             )
#             (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (relu): LeakyReLU(negative_slope=0.1, inplace=True)
#           )
#           (19): IDR_DCRB(
#             (da_conv1): IDR_DDC(
#               (kernel): Sequential(
#                 (0): Linear(in_features=128, out_features=128, bias=False)
#                 (1): LeakyReLU(negative_slope=0.1, inplace=True)
#                 (2): Linear(in_features=128, out_features=1152, bias=False)
#               )
#             )
#             (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (relu): LeakyReLU(negative_slope=0.1, inplace=True)
#           )
#           (20): IDR_DCRB(
#             (da_conv1): IDR_DDC(
#               (kernel): Sequential(
#                 (0): Linear(in_features=128, out_features=128, bias=False)
#                 (1): LeakyReLU(negative_slope=0.1, inplace=True)
#                 (2): Linear(in_features=128, out_features=1152, bias=False)
#               )
#             )
#             (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (relu): LeakyReLU(negative_slope=0.1, inplace=True)
#           )
#           (21): IDR_DCRB(
#             (da_conv1): IDR_DDC(
#               (kernel): Sequential(
#                 (0): Linear(in_features=128, out_features=128, bias=False)
#                 (1): LeakyReLU(negative_slope=0.1, inplace=True)
#                 (2): Linear(in_features=128, out_features=1152, bias=False)
#               )
#             )
#             (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (relu): LeakyReLU(negative_slope=0.1, inplace=True)
#           )
#           (22): IDR_DCRB(
#             (da_conv1): IDR_DDC(
#               (kernel): Sequential(
#                 (0): Linear(in_features=128, out_features=128, bias=False)
#                 (1): LeakyReLU(negative_slope=0.1, inplace=True)
#                 (2): Linear(in_features=128, out_features=1152, bias=False)
#               )
#             )
#             (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (relu): LeakyReLU(negative_slope=0.1, inplace=True)
#           )
#           (23): IDR_DCRB(
#             (da_conv1): IDR_DDC(
#               (kernel): Sequential(
#                 (0): Linear(in_features=128, out_features=128, bias=False)
#                 (1): LeakyReLU(negative_slope=0.1, inplace=True)
#                 (2): Linear(in_features=128, out_features=1152, bias=False)
#               )
#             )
#             (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (relu): LeakyReLU(negative_slope=0.1, inplace=True)
#           )
#           (24): IDR_DCRB(
#             (da_conv1): IDR_DDC(
#               (kernel): Sequential(
#                 (0): Linear(in_features=128, out_features=128, bias=False)
#                 (1): LeakyReLU(negative_slope=0.1, inplace=True)
#                 (2): Linear(in_features=128, out_features=1152, bias=False)
#               )
#             )
#             (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (relu): LeakyReLU(negative_slope=0.1, inplace=True)
#           )
#           (25): IDR_DCRB(
#             (da_conv1): IDR_DDC(
#               (kernel): Sequential(
#                 (0): Linear(in_features=128, out_features=128, bias=False)
#                 (1): LeakyReLU(negative_slope=0.1, inplace=True)
#                 (2): Linear(in_features=128, out_features=1152, bias=False)
#               )
#             )
#             (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (relu): LeakyReLU(negative_slope=0.1, inplace=True)
#           )
#           (26): IDR_DCRB(
#             (da_conv1): IDR_DDC(
#               (kernel): Sequential(
#                 (0): Linear(in_features=128, out_features=128, bias=False)
#                 (1): LeakyReLU(negative_slope=0.1, inplace=True)
#                 (2): Linear(in_features=128, out_features=1152, bias=False)
#               )
#             )
#             (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (relu): LeakyReLU(negative_slope=0.1, inplace=True)
#           )
#           (27): IDR_DCRB(
#             (da_conv1): IDR_DDC(
#               (kernel): Sequential(
#                 (0): Linear(in_features=128, out_features=128, bias=False)
#                 (1): LeakyReLU(negative_slope=0.1, inplace=True)
#                 (2): Linear(in_features=128, out_features=1152, bias=False)
#               )
#             )
#             (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (relu): LeakyReLU(negative_slope=0.1, inplace=True)
#           )
#           (28): IDR_DCRB(
#             (da_conv1): IDR_DDC(
#               (kernel): Sequential(
#                 (0): Linear(in_features=128, out_features=128, bias=False)
#                 (1): LeakyReLU(negative_slope=0.1, inplace=True)
#                 (2): Linear(in_features=128, out_features=1152, bias=False)
#               )
#             )
#             (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (relu): LeakyReLU(negative_slope=0.1, inplace=True)
#           )
#           (29): IDR_DCRB(
#             (da_conv1): IDR_DDC(
#               (kernel): Sequential(
#                 (0): Linear(in_features=128, out_features=128, bias=False)
#                 (1): LeakyReLU(negative_slope=0.1, inplace=True)
#                 (2): Linear(in_features=128, out_features=1152, bias=False)
#               )
#             )
#             (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (relu): LeakyReLU(negative_slope=0.1, inplace=True)
#           )
#           (30): IDR_DCRB(
#             (da_conv1): IDR_DDC(
#               (kernel): Sequential(
#                 (0): Linear(in_features=128, out_features=128, bias=False)
#                 (1): LeakyReLU(negative_slope=0.1, inplace=True)
#                 (2): Linear(in_features=128, out_features=1152, bias=False)
#               )
#             )
#             (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (relu): LeakyReLU(negative_slope=0.1, inplace=True)
#           )
#           (31): IDR_DCRB(
#             (da_conv1): IDR_DDC(
#               (kernel): Sequential(
#                 (0): Linear(in_features=128, out_features=128, bias=False)
#                 (1): LeakyReLU(negative_slope=0.1, inplace=True)
#                 (2): Linear(in_features=128, out_features=1152, bias=False)
#               )
#             )
#             (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (relu): LeakyReLU(negative_slope=0.1, inplace=True)
#           )
#           (32): IDR_DCRB(
#             (da_conv1): IDR_DDC(
#               (kernel): Sequential(
#                 (0): Linear(in_features=128, out_features=128, bias=False)
#                 (1): LeakyReLU(negative_slope=0.1, inplace=True)
#                 (2): Linear(in_features=128, out_features=1152, bias=False)
#               )
#             )
#             (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (relu): LeakyReLU(negative_slope=0.1, inplace=True)
#           )
#           (33): IDR_DCRB(
#             (da_conv1): IDR_DDC(
#               (kernel): Sequential(
#                 (0): Linear(in_features=128, out_features=128, bias=False)
#                 (1): LeakyReLU(negative_slope=0.1, inplace=True)
#                 (2): Linear(in_features=128, out_features=1152, bias=False)
#               )
#             )
#             (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (relu): LeakyReLU(negative_slope=0.1, inplace=True)
#           )
#           (34): IDR_DCRB(
#             (da_conv1): IDR_DDC(
#               (kernel): Sequential(
#                 (0): Linear(in_features=128, out_features=128, bias=False)
#                 (1): LeakyReLU(negative_slope=0.1, inplace=True)
#                 (2): Linear(in_features=128, out_features=1152, bias=False)
#               )
#             )
#             (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (relu): LeakyReLU(negative_slope=0.1, inplace=True)
#           )
#           (35): IDR_DCRB(
#             (da_conv1): IDR_DDC(
#               (kernel): Sequential(
#                 (0): Linear(in_features=128, out_features=128, bias=False)
#                 (1): LeakyReLU(negative_slope=0.1, inplace=True)
#                 (2): Linear(in_features=128, out_features=1152, bias=False)
#               )
#             )
#             (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (relu): LeakyReLU(negative_slope=0.1, inplace=True)
#           )
#           (36): IDR_DCRB(
#             (da_conv1): IDR_DDC(
#               (kernel): Sequential(
#                 (0): Linear(in_features=128, out_features=128, bias=False)
#                 (1): LeakyReLU(negative_slope=0.1, inplace=True)
#                 (2): Linear(in_features=128, out_features=1152, bias=False)
#               )
#             )
#             (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (relu): LeakyReLU(negative_slope=0.1, inplace=True)
#           )
#           (37): IDR_DCRB(
#             (da_conv1): IDR_DDC(
#               (kernel): Sequential(
#                 (0): Linear(in_features=128, out_features=128, bias=False)
#                 (1): LeakyReLU(negative_slope=0.1, inplace=True)
#                 (2): Linear(in_features=128, out_features=1152, bias=False)
#               )
#             )
#             (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (relu): LeakyReLU(negative_slope=0.1, inplace=True)
#           )
#           (38): IDR_DCRB(
#             (da_conv1): IDR_DDC(
#               (kernel): Sequential(
#                 (0): Linear(in_features=128, out_features=128, bias=False)
#                 (1): LeakyReLU(negative_slope=0.1, inplace=True)
#                 (2): Linear(in_features=128, out_features=1152, bias=False)
#               )
#             )
#             (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (relu): LeakyReLU(negative_slope=0.1, inplace=True)
#           )
#           (39): IDR_DCRB(
#             (da_conv1): IDR_DDC(
#               (kernel): Sequential(
#                 (0): Linear(in_features=128, out_features=128, bias=False)
#                 (1): LeakyReLU(negative_slope=0.1, inplace=True)
#                 (2): Linear(in_features=128, out_features=1152, bias=False)
#               )
#             )
#             (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (relu): LeakyReLU(negative_slope=0.1, inplace=True)
#           )
#           (40): IDR_DCRB(
#             (da_conv1): IDR_DDC(
#               (kernel): Sequential(
#                 (0): Linear(in_features=128, out_features=128, bias=False)
#                 (1): LeakyReLU(negative_slope=0.1, inplace=True)
#                 (2): Linear(in_features=128, out_features=1152, bias=False)
#               )
#             )
#             (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (relu): LeakyReLU(negative_slope=0.1, inplace=True)
#           )
#           (41): IDR_DCRB(
#             (da_conv1): IDR_DDC(
#               (kernel): Sequential(
#                 (0): Linear(in_features=128, out_features=128, bias=False)
#                 (1): LeakyReLU(negative_slope=0.1, inplace=True)
#                 (2): Linear(in_features=128, out_features=1152, bias=False)
#               )
#             )
#             (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (relu): LeakyReLU(negative_slope=0.1, inplace=True)
#           )
#         )
#       )
#       (1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#     (tail): Sequential(
#       (0): Upsampler(
#         (0): Conv2d(128, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): PixelShuffle(upscale_factor=2)
#         (2): Conv2d(128, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (3): PixelShuffle(upscale_factor=2)
#       )
#       (1): Conv2d(128, 3, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#   )
#   (E): KD_IDE(
#     (E): Sequential(
#       (0): Conv2d(51, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): LeakyReLU(negative_slope=0.1, inplace=True)
#       (2): ResBlock(
#         (body): Sequential(
#           (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): LeakyReLU(negative_slope=0.1, inplace=True)
#           (2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#       )
#       (3): ResBlock(
#         (body): Sequential(
#           (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): LeakyReLU(negative_slope=0.1, inplace=True)
#           (2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#       )
#       (4): ResBlock(
#         (body): Sequential(
#           (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): LeakyReLU(negative_slope=0.1, inplace=True)
#           (2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#       )
#       (5): ResBlock(
#         (body): Sequential(
#           (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): LeakyReLU(negative_slope=0.1, inplace=True)
#           (2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#       )
#       (6): ResBlock(
#         (body): Sequential(
#           (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): LeakyReLU(negative_slope=0.1, inplace=True)
#           (2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#       )
#       (7): ResBlock(
#         (body): Sequential(
#           (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): LeakyReLU(negative_slope=0.1, inplace=True)
#           (2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#       )
#       (8): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (9): LeakyReLU(negative_slope=0.1, inplace=True)
#       (10): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (11): LeakyReLU(negative_slope=0.1, inplace=True)
#       (12): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (13): LeakyReLU(negative_slope=0.1, inplace=True)
#       (14): AdaptiveAvgPool2d(output_size=1)
#     )
#     (mlp): Sequential(
#       (0): Linear(in_features=512, out_features=512, bias=True)
#       (1): LeakyReLU(negative_slope=0.1, inplace=True)
#       (2): Linear(in_features=512, out_features=512, bias=True)
#       (3): LeakyReLU(negative_slope=0.1, inplace=True)
#     )
#     (compress): Sequential(
#       (0): Linear(in_features=512, out_features=128, bias=True)
#       (1): LeakyReLU(negative_slope=0.1, inplace=True)
#     )
#   )
#   (pixel_unshuffle): PixelUnshuffle(downscale_factor=4)
# )
# 2024-02-03 06:49:00,428 INFO: Use Exponential Moving Average with decay: 0.999
# 2024-02-03 06:49:00,600 INFO: Network [BlindSR_TA] is created.
# 2024-02-03 06:49:00,669 INFO: Loss [L1Loss] is created.
# 2024-02-03 06:49:00,670 WARNING: Params G.sub_mean.weight will not be optimized.
# 2024-02-03 06:49:00,670 WARNING: Params G.sub_mean.bias will not be optimized.
# 2024-02-03 06:49:00,670 WARNING: Params G.add_mean.weight will not be optimized.
# 2024-02-03 06:49:00,670 WARNING: Params G.add_mean.bias will not be optimized.
# 2024-02-03 06:49:00,709 INFO: Model [KDSRNetTAModel] is created.
# 2024-02-03 06:49:00,821 INFO: Start training from epoch: 0, iter: 0
# 2024-02-03 06:49:31,508 INFO: [debug..][epoch:  0, iter:       1, lr:(1.000e-04,)] [eta: 0:00:00, time (data): 30.683 (14.242)] l_pix: 2.6087e-01
# 2024-02-03 06:49:32,119 INFO: [debug..][epoch:  0, iter:       2, lr:(1.000e-04,)] [eta: 0:00:09, time (data): 15.647 (7.126)] l_pix: 2.2014e-01
# 2024-02-03 06:49:32,763 INFO: [debug..][epoch:  0, iter:       3, lr:(1.000e-04,)] [eta: 0:00:14, time (data): 10.646 (4.759)] l_pix: 1.8695e-01
# 2024-02-03 06:49:33,434 INFO: [debug..][epoch:  0, iter:       4, lr:(1.000e-04,)] [eta: 0:00:17, time (data): 8.152 (3.571)] l_pix: 1.9282e-01
# 2024-02-03 06:49:34,136 INFO: [debug..][epoch:  0, iter:       5, lr:(1.000e-04,)] [eta: 0:00:19, time (data): 6.661 (2.860)] l_pix: 1.5346e-01
# 2024-02-03 06:49:34,772 INFO: [debug..][epoch:  0, iter:       6, lr:(1.000e-04,)] [eta: 0:00:20, time (data): 5.657 (2.388)] l_pix: 1.2379e-01
# 2024-02-03 06:49:35,416 INFO: [debug..][epoch:  0, iter:       7, lr:(1.000e-04,)] [eta: 0:00:20, time (data): 4.940 (2.049)] l_pix: 1.0925e-01
# 2024-02-03 06:50:20,296 INFO: [debug..][epoch:  2, iter:      39, lr:(1.000e-04,)] [eta: 0:00:12, time (data): 1.749 (0.671)] l_pix: 6.9267e-02
# 2024-02-03 06:50:21,096 INFO: [debug..][epoch:  2, iter:      40, lr:(1.000e-04,)] [eta: 0:00:10, time (data): 1.724 (0.654)] l_pix: 8.2876e-02
# 2024-02-03 06:50:21,101 INFO: Saving models and training states.
# 2024-02-03 06:50:25,128 INFO: [debug..][epoch:  2, iter:      41, lr:(1.000e-04,)] [eta: 0:00:10, time (data): 1.702 (0.639)] l_pix: 4.7765e-02
# 2024-02-03 06:50:25,801 INFO: [debug..][epoch:  2, iter:      42, lr:(1.000e-04,)] [eta: 0:00:08, time (data): 1.677 (0.624)] l_pix: 6.4043e-02
# 2024-02-03 06:50:26,591 INFO: [debug..][epoch:  2, iter:      43, lr:(1.000e-04,)] [eta: 0:00:07, time (data): 1.656 (0.611)] l_pix: 7.4727e-02
# 2024-02-03 06:50:27,481 INFO: [debug..][epoch:  2, iter:      44, lr:(1.000e-04,)] [eta: 0:00:06, time (data): 1.639 (0.598)] l_pix: 9.2245e-02
# 2024-02-03 06:50:28,442 INFO: [debug..][epoch:  2, iter:      45, lr:(1.000e-04,)] [eta: 0:00:04, time (data): 1.623 (0.587)] l_pix: 8.0537e-02
# 2024-02-03 06:50:29,323 INFO: [debug..][epoch:  2, iter:      46, lr:(1.000e-04,)] [eta: 0:00:03, time (data): 1.607 (0.575)] l_pix: 5.5636e-02
# 2024-02-03 06:50:30,123 INFO: [debug..][epoch:  2, iter:      47, lr:(1.000e-04,)] [eta: 0:00:02, time (data): 1.590 (0.564)] l_pix: 6.2079e-02
# 2024-02-03 06:50:30,867 INFO: [debug..][epoch:  2, iter:      48, lr:(1.000e-04,)] [eta: 0:00:01, time (data): 1.572 (0.552)] l_pix: 7.3966e-02
# 2024-02-03 06:50:30,872 INFO: Saving models and training states.
# 2024-02-03 06:50:33,364 INFO: [debug..][epoch:  2, iter:      49, lr:(1.000e-04,)] [eta: 0:00:00, time (data): 1.555 (0.541)] l_pix: 7.0932e-02
# 2024-02-03 06:50:34,003 INFO: [debug..][epoch:  2, iter:      50, lr:(1.000e-04,)] [eta: -1 day, 23:59:59, time (data): 1.536 (0.530)] l_pix: 5.3805e-02
# 2024-02-03 06:50:38,906 INFO: End of training. Time consumed: 0:01:38
# 2024-02-03 06:50:38,906 INFO: Save the latest model.

# %%
# !python3 kdsrgan/train.py -opt options/train_kdsrnet_x4ST.yml --debug
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/transforms/functional_tensor.py:5: UserWarning: The torchvision.transforms.functional_tensor module is deprecated in 0.15 and will be **removed in 0.17**. Please don't rely on it. You probably just need to use APIs in torchvision.transforms.functional or in torchvision.transforms.v2.functional.
#   warnings.warn(
# Disable distributed.
# Path already exists. Rename it to /content/gdrive/MyDrive/KDSR-GAN/experiments/debug_train_KDSRNetSTx4_1000k_archived_20240203_080331
# 2024-02-03 08:03:31,997 INFO:
#                 ____                _       _____  ____
#                / __ ) ____ _ _____ (_)_____/ ___/ / __ \
#               / __  |/ __ `// ___// // ___/\__ \ / /_/ /
#              / /_/ // /_/ /(__  )/ // /__ ___/ // _, _/
#             /_____/ \__,_//____//_/ \___//____//_/ |_|
#      ______                   __   __                 __      __
#     / ____/____   ____   ____/ /  / /   __  __ _____ / /__   / /
#    / / __ / __ \ / __ \ / __  /  / /   / / / // ___// //_/  / /
#   / /_/ // /_/ // /_/ // /_/ /  / /___/ /_/ // /__ / /<    /_/
#   \____/ \____/ \____/ \____/  /_____/\____/ \___//_/|_|  (_)
#
# Version Information:
# 	BasicSR: 1.4.2
# 	PyTorch: 2.1.0+cu121
# 	TorchVision: 0.16.0+cu121
# 2024-02-03 08:03:31,999 INFO:
#   name: debug_train_KDSRNetSTx4_1000k
#   model_type: KDSRNetSTModel
#   scale: 4
#   num_gpu: 1
#   manual_seed: 0
#   gt_usm: False
#   resize_prob: [0.2, 0.7, 0.1]
#   resize_range: [0.15, 1.5]
#   gaussian_noise_prob: 0.5
#   noise_range: [1, 30]
#   poisson_scale_range: [0.05, 3]
#   gray_noise_prob: 0.4
#   jpeg_range: [30, 95]
#   second_blur_prob: 0.8
#   resize_prob2: [0.3, 0.4, 0.3]
#   resize_range2: [0.3, 1.2]
#   gaussian_noise_prob2: 0.5
#   noise_range2: [1, 25]
#   poisson_scale_range2: [0.05, 2.5]
#   gray_noise_prob2: 0.4
#   jpeg_range2: [30, 95]
#   gt_size: 256
#   queue_size: 180
#   datasets:[
#     train:[
#       name: DF2K+OST
#       type: RealESRGANDataset_basicsr
#       dataroot_gt: /content/gdrive/MyDrive/KDSR-GAN/datasets/DF2K/DF2K_HR
#       meta_info: /content/gdrive/MyDrive/KDSR-GAN/datasets/DF2K/meta_info/meta_info_DF2Kmultiscale.txt
#       io_backend:[
#         type: disk
#       ]
#       blur_kernel_size: 21
#       kernel_list: ['iso', 'aniso', 'generalized_iso', 'generalized_aniso', 'plateau_iso', 'plateau_aniso']
#       kernel_prob: [0.45, 0.25, 0.12, 0.03, 0.12, 0.03]
#       sinc_prob: 0.1
#       blur_sigma: [0.2, 3]
#       betag_range: [0.5, 4]
#       betap_range: [1, 2]
#       blur_kernel_size2: 21
#       kernel_list2: ['iso', 'aniso', 'generalized_iso', 'generalized_aniso', 'plateau_iso', 'plateau_aniso']
#       kernel_prob2: [0.45, 0.25, 0.12, 0.03, 0.12, 0.03]
#       sinc_prob2: 0.1
#       blur_sigma2: [0.2, 1.5]
#       betag_range2: [0.5, 4]
#       betap_range2: [1, 2]
#       final_sinc_prob: 0.8
#       gt_size: 256
#       use_hflip: True
#       use_rot: False
#       use_shuffle: True
#       num_worker_per_gpu: 6
#       batch_size_per_gpu: 9
#       dataset_enlarge_ratio: 1
#       prefetch_mode: None
#       phase: train
#       scale: 4
#     ]
#   ]
#   network_g:[
#     type: BlindSR_ST
#     n_feats: 128
#     n_encoder_res: 6
#     scale: 4
#     n_sr_blocks: 42
#   ]
#   network_TA:[
#     type: BlindSR_TA
#     n_feats: 128
#     n_encoder_res: 6
#     scale: 4
#     n_sr_blocks: 42
#   ]
#   path:[
#     pretrain_network_g: /content/gdrive/MyDrive/KDSR-GAN/experiments/debug_train_KDSRNetTAx4plus_1000k_B12G4/models/net_g_8.pth
#     pretrain_network_TA: /content/gdrive/MyDrive/KDSR-GAN/experiments/debug_train_KDSRNetTAx4plus_1000k_B12G4/models/net_g_8.pth
#     param_key_g: params_ema
#     strict_load_g: False
#     resume_state: None
#     ignore_resume_networks: network_TA
#     experiments_root: /content/gdrive/MyDrive/KDSR-GAN/experiments/debug_train_KDSRNetSTx4_1000k
#     models: /content/gdrive/MyDrive/KDSR-GAN/experiments/debug_train_KDSRNetSTx4_1000k/models
#     training_states: /content/gdrive/MyDrive/KDSR-GAN/experiments/debug_train_KDSRNetSTx4_1000k/training_states
#     log: /content/gdrive/MyDrive/KDSR-GAN/experiments/debug_train_KDSRNetSTx4_1000k
#     visualization: /content/gdrive/MyDrive/KDSR-GAN/experiments/debug_train_KDSRNetSTx4_1000k/visualization
#   ]
#   train:[
#     ema_decay: 0.999
#     optim_g:[
#       type: Adam
#       lr: 0.0002
#       weight_decay: 0
#       betas: [0.9, 0.99]
#     ]
#     scheduler:[
#       type: MultiStepLR
#       milestones: [1000000]
#       gamma: 0.5
#     ]
#     encoder_iter: 50
#     total_iter: 50
#     lr_encoder: 0.0002
#     lr_sr: 0.0002
#     gamma_encoder: 0.1
#     gamma_sr: 0.5
#     lr_decay_encoder: 60000
#     lr_decay_sr: 600000
#     warmup_iter: -1
#     pixel_opt:[
#       type: L1Loss
#       loss_weight: 1.0
#       reduction: mean
#     ]
#     kd_opt:[
#       type: KDLoss
#       loss_weight: 1
#       temperature: 0.15
#     ]
#   ]
#   logger:[
#     print_freq: 1
#     save_checkpoint_freq: 8
#     use_tb_logger: True
#     wandb:[
#       project: None
#       resume_id: None
#     ]
#   ]
#   dist_params:[
#     backend: nccl
#     port: 29500
#   ]
#   dist: False
#   rank: 0
#   world_size: 1
#   auto_resume: False
#   is_train: True
#   root_path: /content/gdrive/MyDrive/KDSR-GAN
#
# 2024-02-03 08:03:32,003 INFO: Dataset [RealESRGANDataset] - DF2K+OST is built.
# 2024-02-03 08:03:32,004 INFO: Training statistics:
# 	Number of train images: 173
# 	Dataset enlarge ratio: 1
# 	Batch size per gpu: 9
# 	World size (gpu number): 1
# 	Require iter number per epoch: 20
# 	Total epochs: 3; iters: 50.
# 2024-02-03 08:03:32,179 INFO: Network [BlindSR_ST] is created.
# 2024-02-03 08:03:32,343 INFO: Network: BlindSR_ST, with parameters: 18,846,107
# 2024-02-03 08:03:32,343 INFO: BlindSR_ST(
#   (G): KDSR(
#     (sub_mean): MeanShift(3, 3, kernel_size=(1, 1), stride=(1, 1))
#     (add_mean): MeanShift(3, 3, kernel_size=(1, 1), stride=(1, 1))
#     (head): Sequential(
#       (0): Conv2d(3, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#     (body): Sequential(
#       (0): DAG(
#         (body): Sequential(
#           (0): IDR_DCRB(
#             (da_conv1): IDR_DDC(
#               (kernel): Sequential(
#                 (0): Linear(in_features=128, out_features=128, bias=False)
#                 (1): LeakyReLU(negative_slope=0.1, inplace=True)
#                 (2): Linear(in_features=128, out_features=1152, bias=False)
#               )
#             )
#             (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (relu): LeakyReLU(negative_slope=0.1, inplace=True)
#           )
#           (1): IDR_DCRB(
#             (da_conv1): IDR_DDC(
#               (kernel): Sequential(
#                 (0): Linear(in_features=128, out_features=128, bias=False)
#                 (1): LeakyReLU(negative_slope=0.1, inplace=True)
#                 (2): Linear(in_features=128, out_features=1152, bias=False)
#               )
#             )
#             (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (relu): LeakyReLU(negative_slope=0.1, inplace=True)
#           )
#           (2): IDR_DCRB(
#             (da_conv1): IDR_DDC(
#               (kernel): Sequential(
#                 (0): Linear(in_features=128, out_features=128, bias=False)
#                 (1): LeakyReLU(negative_slope=0.1, inplace=True)
#                 (2): Linear(in_features=128, out_features=1152, bias=False)
#               )
#             )
#             (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (relu): LeakyReLU(negative_slope=0.1, inplace=True)
#           )
#           (3): IDR_DCRB(
#             (da_conv1): IDR_DDC(
#               (kernel): Sequential(
#                 (0): Linear(in_features=128, out_features=128, bias=False)
#                 (1): LeakyReLU(negative_slope=0.1, inplace=True)
#                 (2): Linear(in_features=128, out_features=1152, bias=False)
#               )
#             )
#             (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (relu): LeakyReLU(negative_slope=0.1, inplace=True)
#           )
#           (4): IDR_DCRB(
#             (da_conv1): IDR_DDC(
#               (kernel): Sequential(
#                 (0): Linear(in_features=128, out_features=128, bias=False)
#                 (1): LeakyReLU(negative_slope=0.1, inplace=True)
#                 (2): Linear(in_features=128, out_features=1152, bias=False)
#               )
#             )
#             (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (relu): LeakyReLU(negative_slope=0.1, inplace=True)
#           )
#           (5): IDR_DCRB(
#             (da_conv1): IDR_DDC(
#               (kernel): Sequential(
#                 (0): Linear(in_features=128, out_features=128, bias=False)
#                 (1): LeakyReLU(negative_slope=0.1, inplace=True)
#                 (2): Linear(in_features=128, out_features=1152, bias=False)
#               )
#             )
#             (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (relu): LeakyReLU(negative_slope=0.1, inplace=True)
#           )
#           (6): IDR_DCRB(
#             (da_conv1): IDR_DDC(
#               (kernel): Sequential(
#                 (0): Linear(in_features=128, out_features=128, bias=False)
#                 (1): LeakyReLU(negative_slope=0.1, inplace=True)
#                 (2): Linear(in_features=128, out_features=1152, bias=False)
#               )
#             )
#             (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (relu): LeakyReLU(negative_slope=0.1, inplace=True)
#           )
#           (7): IDR_DCRB(
#             (da_conv1): IDR_DDC(
#               (kernel): Sequential(
#                 (0): Linear(in_features=128, out_features=128, bias=False)
#                 (1): LeakyReLU(negative_slope=0.1, inplace=True)
#                 (2): Linear(in_features=128, out_features=1152, bias=False)
#               )
#             )
#             (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (relu): LeakyReLU(negative_slope=0.1, inplace=True)
#           )
#           (8): IDR_DCRB(
#             (da_conv1): IDR_DDC(
#               (kernel): Sequential(
#                 (0): Linear(in_features=128, out_features=128, bias=False)
#                 (1): LeakyReLU(negative_slope=0.1, inplace=True)
#                 (2): Linear(in_features=128, out_features=1152, bias=False)
#               )
#             )
#             (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (relu): LeakyReLU(negative_slope=0.1, inplace=True)
#           )
#           (9): IDR_DCRB(
#             (da_conv1): IDR_DDC(
#               (kernel): Sequential(
#                 (0): Linear(in_features=128, out_features=128, bias=False)
#                 (1): LeakyReLU(negative_slope=0.1, inplace=True)
#                 (2): Linear(in_features=128, out_features=1152, bias=False)
#               )
#             )
#             (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (relu): LeakyReLU(negative_slope=0.1, inplace=True)
#           )
#           (10): IDR_DCRB(
#             (da_conv1): IDR_DDC(
#               (kernel): Sequential(
#                 (0): Linear(in_features=128, out_features=128, bias=False)
#                 (1): LeakyReLU(negative_slope=0.1, inplace=True)
#                 (2): Linear(in_features=128, out_features=1152, bias=False)
#               )
#             )
#             (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (relu): LeakyReLU(negative_slope=0.1, inplace=True)
#           )
#           (11): IDR_DCRB(
#             (da_conv1): IDR_DDC(
#               (kernel): Sequential(
#                 (0): Linear(in_features=128, out_features=128, bias=False)
#                 (1): LeakyReLU(negative_slope=0.1, inplace=True)
#                 (2): Linear(in_features=128, out_features=1152, bias=False)
#               )
#             )
#             (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (relu): LeakyReLU(negative_slope=0.1, inplace=True)
#           )
#           (12): IDR_DCRB(
#             (da_conv1): IDR_DDC(
#               (kernel): Sequential(
#                 (0): Linear(in_features=128, out_features=128, bias=False)
#                 (1): LeakyReLU(negative_slope=0.1, inplace=True)
#                 (2): Linear(in_features=128, out_features=1152, bias=False)
#               )
#             )
#             (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (relu): LeakyReLU(negative_slope=0.1, inplace=True)
#           )
#           (13): IDR_DCRB(
#             (da_conv1): IDR_DDC(
#               (kernel): Sequential(
#                 (0): Linear(in_features=128, out_features=128, bias=False)
#                 (1): LeakyReLU(negative_slope=0.1, inplace=True)
#                 (2): Linear(in_features=128, out_features=1152, bias=False)
#               )
#             )
#             (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (relu): LeakyReLU(negative_slope=0.1, inplace=True)
#           )
#           (14): IDR_DCRB(
#             (da_conv1): IDR_DDC(
#               (kernel): Sequential(
#                 (0): Linear(in_features=128, out_features=128, bias=False)
#                 (1): LeakyReLU(negative_slope=0.1, inplace=True)
#                 (2): Linear(in_features=128, out_features=1152, bias=False)
#               )
#             )
#             (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (relu): LeakyReLU(negative_slope=0.1, inplace=True)
#           )
#           (15): IDR_DCRB(
#             (da_conv1): IDR_DDC(
#               (kernel): Sequential(
#                 (0): Linear(in_features=128, out_features=128, bias=False)
#                 (1): LeakyReLU(negative_slope=0.1, inplace=True)
#                 (2): Linear(in_features=128, out_features=1152, bias=False)
#               )
#             )
#             (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (relu): LeakyReLU(negative_slope=0.1, inplace=True)
#           )
#           (16): IDR_DCRB(
#             (da_conv1): IDR_DDC(
#               (kernel): Sequential(
#                 (0): Linear(in_features=128, out_features=128, bias=False)
#                 (1): LeakyReLU(negative_slope=0.1, inplace=True)
#                 (2): Linear(in_features=128, out_features=1152, bias=False)
#               )
#             )
#             (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (relu): LeakyReLU(negative_slope=0.1, inplace=True)
#           )
#           (17): IDR_DCRB(
#             (da_conv1): IDR_DDC(
#               (kernel): Sequential(
#                 (0): Linear(in_features=128, out_features=128, bias=False)
#                 (1): LeakyReLU(negative_slope=0.1, inplace=True)
#                 (2): Linear(in_features=128, out_features=1152, bias=False)
#               )
#             )
#             (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (relu): LeakyReLU(negative_slope=0.1, inplace=True)
#           )
#           (18): IDR_DCRB(
#             (da_conv1): IDR_DDC(
#               (kernel): Sequential(
#                 (0): Linear(in_features=128, out_features=128, bias=False)
#                 (1): LeakyReLU(negative_slope=0.1, inplace=True)
#                 (2): Linear(in_features=128, out_features=1152, bias=False)
#               )
#             )
#             (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (relu): LeakyReLU(negative_slope=0.1, inplace=True)
#           )
#           (19): IDR_DCRB(
#             (da_conv1): IDR_DDC(
#               (kernel): Sequential(
#                 (0): Linear(in_features=128, out_features=128, bias=False)
#                 (1): LeakyReLU(negative_slope=0.1, inplace=True)
#                 (2): Linear(in_features=128, out_features=1152, bias=False)
#               )
#             )
#             (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (relu): LeakyReLU(negative_slope=0.1, inplace=True)
#           )
#           (20): IDR_DCRB(
#             (da_conv1): IDR_DDC(
#               (kernel): Sequential(
#                 (0): Linear(in_features=128, out_features=128, bias=False)
#                 (1): LeakyReLU(negative_slope=0.1, inplace=True)
#                 (2): Linear(in_features=128, out_features=1152, bias=False)
#               )
#             )
#             (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (relu): LeakyReLU(negative_slope=0.1, inplace=True)
#           )
#           (21): IDR_DCRB(
#             (da_conv1): IDR_DDC(
#               (kernel): Sequential(
#                 (0): Linear(in_features=128, out_features=128, bias=False)
#                 (1): LeakyReLU(negative_slope=0.1, inplace=True)
#                 (2): Linear(in_features=128, out_features=1152, bias=False)
#               )
#             )
#             (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (relu): LeakyReLU(negative_slope=0.1, inplace=True)
#           )
#           (22): IDR_DCRB(
#             (da_conv1): IDR_DDC(
#               (kernel): Sequential(
#                 (0): Linear(in_features=128, out_features=128, bias=False)
#                 (1): LeakyReLU(negative_slope=0.1, inplace=True)
#                 (2): Linear(in_features=128, out_features=1152, bias=False)
#               )
#             )
#             (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (relu): LeakyReLU(negative_slope=0.1, inplace=True)
#           )
#           (23): IDR_DCRB(
#             (da_conv1): IDR_DDC(
#               (kernel): Sequential(
#                 (0): Linear(in_features=128, out_features=128, bias=False)
#                 (1): LeakyReLU(negative_slope=0.1, inplace=True)
#                 (2): Linear(in_features=128, out_features=1152, bias=False)
#               )
#             )
#             (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (relu): LeakyReLU(negative_slope=0.1, inplace=True)
#           )
#           (24): IDR_DCRB(
#             (da_conv1): IDR_DDC(
#               (kernel): Sequential(
#                 (0): Linear(in_features=128, out_features=128, bias=False)
#                 (1): LeakyReLU(negative_slope=0.1, inplace=True)
#                 (2): Linear(in_features=128, out_features=1152, bias=False)
#               )
#             )
#             (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (relu): LeakyReLU(negative_slope=0.1, inplace=True)
#           )
#           (25): IDR_DCRB(
#             (da_conv1): IDR_DDC(
#               (kernel): Sequential(
#                 (0): Linear(in_features=128, out_features=128, bias=False)
#                 (1): LeakyReLU(negative_slope=0.1, inplace=True)
#                 (2): Linear(in_features=128, out_features=1152, bias=False)
#               )
#             )
#             (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (relu): LeakyReLU(negative_slope=0.1, inplace=True)
#           )
#           (26): IDR_DCRB(
#             (da_conv1): IDR_DDC(
#               (kernel): Sequential(
#                 (0): Linear(in_features=128, out_features=128, bias=False)
#                 (1): LeakyReLU(negative_slope=0.1, inplace=True)
#                 (2): Linear(in_features=128, out_features=1152, bias=False)
#               )
#             )
#             (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (relu): LeakyReLU(negative_slope=0.1, inplace=True)
#           )
#           (27): IDR_DCRB(
#             (da_conv1): IDR_DDC(
#               (kernel): Sequential(
#                 (0): Linear(in_features=128, out_features=128, bias=False)
#                 (1): LeakyReLU(negative_slope=0.1, inplace=True)
#                 (2): Linear(in_features=128, out_features=1152, bias=False)
#               )
#             )
#             (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (relu): LeakyReLU(negative_slope=0.1, inplace=True)
#           )
#           (28): IDR_DCRB(
#             (da_conv1): IDR_DDC(
#               (kernel): Sequential(
#                 (0): Linear(in_features=128, out_features=128, bias=False)
#                 (1): LeakyReLU(negative_slope=0.1, inplace=True)
#                 (2): Linear(in_features=128, out_features=1152, bias=False)
#               )
#             )
#             (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (relu): LeakyReLU(negative_slope=0.1, inplace=True)
#           )
#           (29): IDR_DCRB(
#             (da_conv1): IDR_DDC(
#               (kernel): Sequential(
#                 (0): Linear(in_features=128, out_features=128, bias=False)
#                 (1): LeakyReLU(negative_slope=0.1, inplace=True)
#                 (2): Linear(in_features=128, out_features=1152, bias=False)
#               )
#             )
#             (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (relu): LeakyReLU(negative_slope=0.1, inplace=True)
#           )
#           (30): IDR_DCRB(
#             (da_conv1): IDR_DDC(
#               (kernel): Sequential(
#                 (0): Linear(in_features=128, out_features=128, bias=False)
#                 (1): LeakyReLU(negative_slope=0.1, inplace=True)
#                 (2): Linear(in_features=128, out_features=1152, bias=False)
#               )
#             )
#             (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (relu): LeakyReLU(negative_slope=0.1, inplace=True)
#           )
#           (31): IDR_DCRB(
#             (da_conv1): IDR_DDC(
#               (kernel): Sequential(
#                 (0): Linear(in_features=128, out_features=128, bias=False)
#                 (1): LeakyReLU(negative_slope=0.1, inplace=True)
#                 (2): Linear(in_features=128, out_features=1152, bias=False)
#               )
#             )
#             (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (relu): LeakyReLU(negative_slope=0.1, inplace=True)
#           )
#           (32): IDR_DCRB(
#             (da_conv1): IDR_DDC(
#               (kernel): Sequential(
#                 (0): Linear(in_features=128, out_features=128, bias=False)
#                 (1): LeakyReLU(negative_slope=0.1, inplace=True)
#                 (2): Linear(in_features=128, out_features=1152, bias=False)
#               )
#             )
#             (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (relu): LeakyReLU(negative_slope=0.1, inplace=True)
#           )
#           (33): IDR_DCRB(
#             (da_conv1): IDR_DDC(
#               (kernel): Sequential(
#                 (0): Linear(in_features=128, out_features=128, bias=False)
#                 (1): LeakyReLU(negative_slope=0.1, inplace=True)
#                 (2): Linear(in_features=128, out_features=1152, bias=False)
#               )
#             )
#             (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (relu): LeakyReLU(negative_slope=0.1, inplace=True)
#           )
#           (34): IDR_DCRB(
#             (da_conv1): IDR_DDC(
#               (kernel): Sequential(
#                 (0): Linear(in_features=128, out_features=128, bias=False)
#                 (1): LeakyReLU(negative_slope=0.1, inplace=True)
#                 (2): Linear(in_features=128, out_features=1152, bias=False)
#               )
#             )
#             (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (relu): LeakyReLU(negative_slope=0.1, inplace=True)
#           )
#           (35): IDR_DCRB(
#             (da_conv1): IDR_DDC(
#               (kernel): Sequential(
#                 (0): Linear(in_features=128, out_features=128, bias=False)
#                 (1): LeakyReLU(negative_slope=0.1, inplace=True)
#                 (2): Linear(in_features=128, out_features=1152, bias=False)
#               )
#             )
#             (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (relu): LeakyReLU(negative_slope=0.1, inplace=True)
#           )
#           (36): IDR_DCRB(
#             (da_conv1): IDR_DDC(
#               (kernel): Sequential(
#                 (0): Linear(in_features=128, out_features=128, bias=False)
#                 (1): LeakyReLU(negative_slope=0.1, inplace=True)
#                 (2): Linear(in_features=128, out_features=1152, bias=False)
#               )
#             )
#             (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (relu): LeakyReLU(negative_slope=0.1, inplace=True)
#           )
#           (37): IDR_DCRB(
#             (da_conv1): IDR_DDC(
#               (kernel): Sequential(
#                 (0): Linear(in_features=128, out_features=128, bias=False)
#                 (1): LeakyReLU(negative_slope=0.1, inplace=True)
#                 (2): Linear(in_features=128, out_features=1152, bias=False)
#               )
#             )
#             (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (relu): LeakyReLU(negative_slope=0.1, inplace=True)
#           )
#           (38): IDR_DCRB(
#             (da_conv1): IDR_DDC(
#               (kernel): Sequential(
#                 (0): Linear(in_features=128, out_features=128, bias=False)
#                 (1): LeakyReLU(negative_slope=0.1, inplace=True)
#                 (2): Linear(in_features=128, out_features=1152, bias=False)
#               )
#             )
#             (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (relu): LeakyReLU(negative_slope=0.1, inplace=True)
#           )
#           (39): IDR_DCRB(
#             (da_conv1): IDR_DDC(
#               (kernel): Sequential(
#                 (0): Linear(in_features=128, out_features=128, bias=False)
#                 (1): LeakyReLU(negative_slope=0.1, inplace=True)
#                 (2): Linear(in_features=128, out_features=1152, bias=False)
#               )
#             )
#             (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (relu): LeakyReLU(negative_slope=0.1, inplace=True)
#           )
#           (40): IDR_DCRB(
#             (da_conv1): IDR_DDC(
#               (kernel): Sequential(
#                 (0): Linear(in_features=128, out_features=128, bias=False)
#                 (1): LeakyReLU(negative_slope=0.1, inplace=True)
#                 (2): Linear(in_features=128, out_features=1152, bias=False)
#               )
#             )
#             (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (relu): LeakyReLU(negative_slope=0.1, inplace=True)
#           )
#           (41): IDR_DCRB(
#             (da_conv1): IDR_DDC(
#               (kernel): Sequential(
#                 (0): Linear(in_features=128, out_features=128, bias=False)
#                 (1): LeakyReLU(negative_slope=0.1, inplace=True)
#                 (2): Linear(in_features=128, out_features=1152, bias=False)
#               )
#             )
#             (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (relu): LeakyReLU(negative_slope=0.1, inplace=True)
#           )
#         )
#       )
#       (1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#     (tail): Sequential(
#       (0): Upsampler(
#         (0): Conv2d(128, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): PixelShuffle(upscale_factor=2)
#         (2): Conv2d(128, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (3): PixelShuffle(upscale_factor=2)
#       )
#       (1): Conv2d(128, 3, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#   )
#   (E_st): KD_IDE(
#     (E): Sequential(
#       (0): Conv2d(3, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): LeakyReLU(negative_slope=0.1, inplace=True)
#       (2): ResBlock(
#         (body): Sequential(
#           (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): LeakyReLU(negative_slope=0.1, inplace=True)
#           (2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#       )
#       (3): ResBlock(
#         (body): Sequential(
#           (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): LeakyReLU(negative_slope=0.1, inplace=True)
#           (2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#       )
#       (4): ResBlock(
#         (body): Sequential(
#           (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): LeakyReLU(negative_slope=0.1, inplace=True)
#           (2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#       )
#       (5): ResBlock(
#         (body): Sequential(
#           (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): LeakyReLU(negative_slope=0.1, inplace=True)
#           (2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#       )
#       (6): ResBlock(
#         (body): Sequential(
#           (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): LeakyReLU(negative_slope=0.1, inplace=True)
#           (2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#       )
#       (7): ResBlock(
#         (body): Sequential(
#           (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): LeakyReLU(negative_slope=0.1, inplace=True)
#           (2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#       )
#       (8): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (9): LeakyReLU(negative_slope=0.1, inplace=True)
#       (10): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (11): LeakyReLU(negative_slope=0.1, inplace=True)
#       (12): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (13): LeakyReLU(negative_slope=0.1, inplace=True)
#       (14): AdaptiveAvgPool2d(output_size=1)
#     )
#     (mlp): Sequential(
#       (0): Linear(in_features=512, out_features=512, bias=True)
#       (1): LeakyReLU(negative_slope=0.1, inplace=True)
#       (2): Linear(in_features=512, out_features=512, bias=True)
#       (3): LeakyReLU(negative_slope=0.1, inplace=True)
#     )
#     (compress): Sequential(
#       (0): Linear(in_features=512, out_features=128, bias=True)
#       (1): LeakyReLU(negative_slope=0.1, inplace=True)
#     )
#   )
#   (pixel_unshuffle): PixelUnshuffle(downscale_factor=4)
# )
# 2024-02-03 08:03:32,695 INFO: Loading BlindSR_ST model from /content/gdrive/MyDrive/KDSR-GAN/experiments/debug_train_KDSRNetTAx4plus_1000k_B12G4/models/net_g_8.pth, with param key: [params_ema].
# 2024-02-03 08:03:32,724 WARNING: Current net - loaded net:
# 2024-02-03 08:03:32,724 WARNING:   E_st.E.0.bias
# 2024-02-03 08:03:32,725 WARNING:   E_st.E.0.weight
# 2024-02-03 08:03:32,725 WARNING:   E_st.E.10.bias
# 2024-02-03 08:03:32,725 WARNING:   E_st.E.10.weight
# 2024-02-03 08:03:32,725 WARNING:   E_st.E.12.bias
# 2024-02-03 08:03:32,725 WARNING:   E_st.E.12.weight
# 2024-02-03 08:03:32,725 WARNING:   E_st.E.2.body.0.bias
# 2024-02-03 08:03:32,725 WARNING:   E_st.E.2.body.0.weight
# 2024-02-03 08:03:32,726 WARNING:   E_st.E.2.body.2.bias
# 2024-02-03 08:03:32,726 WARNING:   E_st.E.2.body.2.weight
# 2024-02-03 08:03:32,726 WARNING:   E_st.E.3.body.0.bias
# 2024-02-03 08:03:32,726 WARNING:   E_st.E.3.body.0.weight
# 2024-02-03 08:03:32,726 WARNING:   E_st.E.3.body.2.bias
# 2024-02-03 08:03:32,726 WARNING:   E_st.E.3.body.2.weight
# 2024-02-03 08:03:32,726 WARNING:   E_st.E.4.body.0.bias
# 2024-02-03 08:03:32,726 WARNING:   E_st.E.4.body.0.weight
# 2024-02-03 08:03:32,727 WARNING:   E_st.E.4.body.2.bias
# 2024-02-03 08:03:32,727 WARNING:   E_st.E.4.body.2.weight
# 2024-02-03 08:03:32,727 WARNING:   E_st.E.5.body.0.bias
# 2024-02-03 08:03:32,727 WARNING:   E_st.E.5.body.0.weight
# 2024-02-03 08:03:32,727 WARNING:   E_st.E.5.body.2.bias
# 2024-02-03 08:03:32,727 WARNING:   E_st.E.5.body.2.weight
# 2024-02-03 08:03:32,727 WARNING:   E_st.E.6.body.0.bias
# 2024-02-03 08:03:32,727 WARNING:   E_st.E.6.body.0.weight
# 2024-02-03 08:03:32,728 WARNING:   E_st.E.6.body.2.bias
# 2024-02-03 08:03:32,728 WARNING:   E_st.E.6.body.2.weight
# 2024-02-03 08:03:32,728 WARNING:   E_st.E.7.body.0.bias
# 2024-02-03 08:03:32,728 WARNING:   E_st.E.7.body.0.weight
# 2024-02-03 08:03:32,728 WARNING:   E_st.E.7.body.2.bias
# 2024-02-03 08:03:32,728 WARNING:   E_st.E.7.body.2.weight
# 2024-02-03 08:03:32,728 WARNING:   E_st.E.8.bias
# 2024-02-03 08:03:32,728 WARNING:   E_st.E.8.weight
# 2024-02-03 08:03:32,729 WARNING:   E_st.compress.0.bias
# 2024-02-03 08:03:32,729 WARNING:   E_st.compress.0.weight
# 2024-02-03 08:03:32,729 WARNING:   E_st.mlp.0.bias
# 2024-02-03 08:03:32,729 WARNING:   E_st.mlp.0.weight
# 2024-02-03 08:03:32,729 WARNING:   E_st.mlp.2.bias
# 2024-02-03 08:03:32,729 WARNING:   E_st.mlp.2.weight
# 2024-02-03 08:03:32,729 WARNING: Loaded net - current net:
# 2024-02-03 08:03:32,730 WARNING:   E.E.0.bias
# 2024-02-03 08:03:32,730 WARNING:   E.E.0.weight
# 2024-02-03 08:04:57,591 INFO: [debug..][epoch:  2, iter:      46, lr:(2.000e-04,)] [eta: 0:00:03, time (data): 1.533 (0.484)] l_pix: 6.8061e-02 l_kd: 5.5866e-04
# 2024-02-03 08:04:58,368 INFO: [debug..][epoch:  2, iter:      47, lr:(2.000e-04,)] [eta: 0:00:02, time (data): 1.517 (0.474)] l_pix: 7.0395e-02 l_kd: 3.9708e-04
# 2024-02-03 08:04:59,107 INFO: [debug..][epoch:  2, iter:      48, lr:(2.000e-04,)] [eta: 0:00:01, time (data): 1.501 (0.464)] l_pix: 7.5028e-02 l_kd: 1.4275e-04
# 2024-02-03 08:04:59,107 INFO: Saving models and training states.
# 2024-02-03 08:05:01,378 INFO: [debug..][epoch:  2, iter:      49, lr:(2.000e-04,)] [eta: 0:00:00, time (data): 1.483 (0.455)] l_pix: 6.0635e-02 l_kd: 2.8756e-04
# 2024-02-03 08:05:02,051 INFO: [debug..][epoch:  2, iter:      50, lr:(2.000e-04,)] [eta: -1 day, 23:59:59, time (data): 1.467 (0.446)] l_pix: 5.1605e-02 l_kd: 5.5377e-04
# 2024-02-03 08:05:08,043 INFO: End of training. Time consumed: 0:01:33
# 2024-02-03 08:05:08,043 INFO: Save the latest model.

# %%
# !python3 kdsrgan/train.py -opt options/train_kdsrgan_x4ST.yml
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/transforms/functional_tensor.py:5: UserWarning: The torchvision.transforms.functional_tensor module is deprecated in 0.15 and will be **removed in 0.17**. Please don't rely on it. You probably just need to use APIs in torchvision.transforms.functional or in torchvision.transforms.v2.functional.
#   warnings.warn(
# Disable distributed.
# Path already exists. Rename it to /content/gdrive/MyDrive/KDSR-GAN/experiments/train_KDSRGANx4STplus_400k_B12G4_archived_20240203_081405
# Path already exists. Rename it to /content/gdrive/MyDrive/KDSR-GAN/tb_logger/train_KDSRGANx4STplus_400k_B12G4_archived_20240203_081405
# 2024-02-03 08:14:05,323 INFO:
#                 ____                _       _____  ____
#                / __ ) ____ _ _____ (_)_____/ ___/ / __ \
#               / __  |/ __ `// ___// // ___/\__ \ / /_/ /
#              / /_/ // /_/ /(__  )/ // /__ ___/ // _, _/
#             /_____/ \__,_//____//_/ \___//____//_/ |_|
#      ______                   __   __                 __      __
#     / ____/____   ____   ____/ /  / /   __  __ _____ / /__   / /
#    / / __ / __ \ / __ \ / __  /  / /   / / / // ___// //_/  / /
#   / /_/ // /_/ // /_/ // /_/ /  / /___/ /_/ // /__ / /<    /_/
#   \____/ \____/ \____/ \____/  /_____/\____/ \___//_/|_|  (_)
#
# Version Information:
# 	BasicSR: 1.4.2
# 	PyTorch: 2.1.0+cu121
# 	TorchVision: 0.16.0+cu121
# 2024-02-03 08:14:05,325 INFO:
#   name: train_KDSRGANx4STplus_400k_B12G4
#   model_type: KDSRGANSTModel
#   scale: 4
#   num_gpu: 1
#   manual_seed: 0
#   l1_gt_usm: False
#   percep_gt_usm: False
#   gan_gt_usm: False
#   resize_prob: [0.2, 0.7, 0.1]
#   resize_range: [0.15, 1.5]
#   gaussian_noise_prob: 0.5
#   noise_range: [1, 30]
#   poisson_scale_range: [0.05, 3]
#   gray_noise_prob: 0.4
#   jpeg_range: [30, 95]
#   second_blur_prob: 0.8
#   resize_prob2: [0.3, 0.4, 0.3]
#   resize_range2: [0.3, 1.2]
#   gaussian_noise_prob2: 0.5
#   noise_range2: [1, 25]
#   poisson_scale_range2: [0.05, 2.5]
#   gray_noise_prob2: 0.4
#   jpeg_range2: [30, 95]
#   gt_size: 256
#   queue_size: 180
#   datasets:[
#     train:[
#       name: DF2K+OST
#       type: RealESRGANDataset_basicsr
#       dataroot_gt: /content/gdrive/MyDrive/KDSR-GAN/datasets/DF2K/DF2K_HR
#       meta_info: /content/gdrive/MyDrive/KDSR-GAN/datasets/DF2K/meta_info/meta_info_DF2Kmultiscale.txt
#       io_backend:[
#         type: disk
#       ]
#       blur_kernel_size: 21
#       kernel_list: ['iso', 'aniso', 'generalized_iso', 'generalized_aniso', 'plateau_iso', 'plateau_aniso']
#       kernel_prob: [0.45, 0.25, 0.12, 0.03, 0.12, 0.03]
#       sinc_prob: 0.1
#       blur_sigma: [0.2, 3]
#       betag_range: [0.5, 4]
#       betap_range: [1, 2]
#       blur_kernel_size2: 21
#       kernel_list2: ['iso', 'aniso', 'generalized_iso', 'generalized_aniso', 'plateau_iso', 'plateau_aniso']
#       kernel_prob2: [0.45, 0.25, 0.12, 0.03, 0.12, 0.03]
#       sinc_prob2: 0.1
#       blur_sigma2: [0.2, 1.5]
#       betag_range2: [0.5, 4]
#       betap_range2: [1, 2]
#       final_sinc_prob: 0.8
#       gt_size: 256
#       use_hflip: True
#       use_rot: False
#       use_shuffle: True
#       num_worker_per_gpu: 6
#       batch_size_per_gpu: 9
#       dataset_enlarge_ratio: 1
#       prefetch_mode: None
#       phase: train
#       scale: 4
#     ]
#   ]
#   network_g:[
#     type: BlindSR_ST
#     n_feats: 128
#     n_encoder_res: 6
#     scale: 4
#     n_sr_blocks: 42
#   ]
#   network_TA:[
#     type: BlindSR_TA
#     n_feats: 128
#     n_encoder_res: 6
#     scale: 4
#     n_sr_blocks: 42
#   ]
#   network_d:[
#     type: UNetDiscriminatorSN
#     num_in_ch: 3
#     num_feat: 64
#     skip_connection: True
#   ]
#   path:[
#     pretrain_network_TA: /content/gdrive/MyDrive/KDSR-GAN/experiments/debug_train_KDSRNetTAx4plus_1000k_B12G4/models/net_g_8.pth
#     pretrain_network_g: /content/gdrive/MyDrive/KDSR-GAN/experiments/debug_train_KDSRNetSTx4_1000k/models/net_g_8.pth
#     param_key_g: params_ema
#     strict_load_g: True
#     resume_state: None
#     ignore_resume_networks: network_TA
#     experiments_root: /content/gdrive/MyDrive/KDSR-GAN/experiments/train_KDSRGANx4STplus_400k_B12G4
#     models: /content/gdrive/MyDrive/KDSR-GAN/experiments/train_KDSRGANx4STplus_400k_B12G4/models
#     training_states: /content/gdrive/MyDrive/KDSR-GAN/experiments/train_KDSRGANx4STplus_400k_B12G4/training_states
#     log: /content/gdrive/MyDrive/KDSR-GAN/experiments/train_KDSRGANx4STplus_400k_B12G4
#     visualization: /content/gdrive/MyDrive/KDSR-GAN/experiments/train_KDSRGANx4STplus_400k_B12G4/visualization
#   ]
#   train:[
#     ema_decay: 0.999
#     optim_g:[
#       type: Adam
#       lr: 0.0001
#       weight_decay: 0
#       betas: [0.9, 0.99]
#     ]
#     optim_d:[
#       type: Adam
#       lr: 0.0001
#       weight_decay: 0
#       betas: [0.9, 0.99]
#     ]
#     scheduler:[
#       type: MultiStepLR
#       milestones: [400000]
#       gamma: 0.5
#     ]
#     encoder_iter: 50
#     total_iter: 50
#     lr_encoder: 0.0002
#     lr_sr: 0.0001
#     gamma_encoder: 0.1
#     gamma_sr: 0.5
#     lr_decay_encoder: 60000
#     lr_decay_sr: 400000
#     warmup_iter: -1
#     pixel_opt:[
#       type: L1Loss
#       loss_weight: 1.0
#       reduction: mean
#     ]
#     perceptual_opt:[
#       type: PerceptualLoss
#       layer_weights:[
#         conv1_2: 0.1
#         conv2_2: 0.1
#         conv3_4: 1
#         conv4_4: 1
#         conv5_4: 1
#       ]
#       vgg_type: vgg19
#       use_input_norm: True
#       perceptual_weight: 1.0
#       style_weight: 0
#       range_norm: False
#       criterion: l1
#     ]
#     gan_opt:[
#       type: GANLoss
#       gan_type: vanilla
#       real_label_val: 1.0
#       fake_label_val: 0.0
#       loss_weight: 1.0
#     ]
#     kd_opt:[
#       type: KDLoss
#       loss_weight: 1
#       temperature: 0.15
#     ]
#     net_d_iters: 1
#     net_d_init_iters: 0
#   ]
#   logger:[
#     print_freq: 100
#     save_checkpoint_freq: 10000.0
#     use_tb_logger: True
#     wandb:[
#       project: None
#       resume_id: None
#     ]
#   ]
#   dist_params:[
#     backend: nccl
#     port: 29500
#   ]
#   dist: False
#   rank: 0
#   world_size: 1
#   auto_resume: False
#   is_train: True
#   root_path: /content/gdrive/MyDrive/KDSR-GAN
#
# 2024-02-03 08:14:05.803369: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-02-03 08:14:05.803419: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-02-03 08:14:05.804718: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-02-03 08:14:06.938608: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-02-03 08:14:07,858 INFO: Dataset [RealESRGANDataset] - DF2K+OST is built.
# 2024-02-03 08:14:07,859 INFO: Training statistics:
# 	Number of train images: 173
# 	Dataset enlarge ratio: 1
# 	Batch size per gpu: 9
# 	World size (gpu number): 1
# 	Require iter number per epoch: 20
# 	Total epochs: 3; iters: 50.
# 2024-02-03 08:14:08,027 INFO: Network [BlindSR_ST] is created.
# 2024-02-03 08:14:08,209 INFO: Network: BlindSR_ST, with parameters: 18,846,107
# 2024-02-03 08:14:08,209 INFO: BlindSR_ST(
#   (G): KDSR(
#     (sub_mean): MeanShift(3, 3, kernel_size=(1, 1), stride=(1, 1))
#     (add_mean): MeanShift(3, 3, kernel_size=(1, 1), stride=(1, 1))
#     (head): Sequential(
#       (0): Conv2d(3, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#     (body): Sequential(
#       (0): DAG(
#         (body): Sequential(
#           (0): IDR_DCRB(
#             (da_conv1): IDR_DDC(
#               (kernel): Sequential(
#                 (0): Linear(in_features=128, out_features=128, bias=False)
#                 (1): LeakyReLU(negative_slope=0.1, inplace=True)
#                 (2): Linear(in_features=128, out_features=1152, bias=False)
#               )
#             )
#             (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (relu): LeakyReLU(negative_slope=0.1, inplace=True)
#           )
#           (1): IDR_DCRB(
#             (da_conv1): IDR_DDC(
#               (kernel): Sequential(
#                 (0): Linear(in_features=128, out_features=128, bias=False)
#                 (1): LeakyReLU(negative_slope=0.1, inplace=True)
#                 (2): Linear(in_features=128, out_features=1152, bias=False)
#               )
#             )
#             (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (relu): LeakyReLU(negative_slope=0.1, inplace=True)
#           )
#           (2): IDR_DCRB(
#             (da_conv1): IDR_DDC(
#               (kernel): Sequential(
#                 (0): Linear(in_features=128, out_features=128, bias=False)
#                 (1): LeakyReLU(negative_slope=0.1, inplace=True)
#                 (2): Linear(in_features=128, out_features=1152, bias=False)
#               )
#             )
#             (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (relu): LeakyReLU(negative_slope=0.1, inplace=True)
#           )
#           (3): IDR_DCRB(
#             (da_conv1): IDR_DDC(
#               (kernel): Sequential(
#                 (0): Linear(in_features=128, out_features=128, bias=False)
#                 (1): LeakyReLU(negative_slope=0.1, inplace=True)
#                 (2): Linear(in_features=128, out_features=1152, bias=False)
#               )
#             )
#             (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (relu): LeakyReLU(negative_slope=0.1, inplace=True)
#           )
#           (4): IDR_DCRB(
#             (da_conv1): IDR_DDC(
#               (kernel): Sequential(
#                 (0): Linear(in_features=128, out_features=128, bias=False)
#                 (1): LeakyReLU(negative_slope=0.1, inplace=True)
#                 (2): Linear(in_features=128, out_features=1152, bias=False)
#               )
#             )
#             (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (relu): LeakyReLU(negative_slope=0.1, inplace=True)
#           )
#           (5): IDR_DCRB(
#             (da_conv1): IDR_DDC(
#               (kernel): Sequential(
#                 (0): Linear(in_features=128, out_features=128, bias=False)
#                 (1): LeakyReLU(negative_slope=0.1, inplace=True)
#                 (2): Linear(in_features=128, out_features=1152, bias=False)
#               )
#             )
#             (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (relu): LeakyReLU(negative_slope=0.1, inplace=True)
#           )
#           (6): IDR_DCRB(
#             (da_conv1): IDR_DDC(
#               (kernel): Sequential(
#                 (0): Linear(in_features=128, out_features=128, bias=False)
#                 (1): LeakyReLU(negative_slope=0.1, inplace=True)
#                 (2): Linear(in_features=128, out_features=1152, bias=False)
#               )
#             )
#             (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (relu): LeakyReLU(negative_slope=0.1, inplace=True)
#           )
#           (7): IDR_DCRB(
#             (da_conv1): IDR_DDC(
#               (kernel): Sequential(
#                 (0): Linear(in_features=128, out_features=128, bias=False)
#                 (1): LeakyReLU(negative_slope=0.1, inplace=True)
#                 (2): Linear(in_features=128, out_features=1152, bias=False)
#               )
#             )
#             (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (relu): LeakyReLU(negative_slope=0.1, inplace=True)
#           )
#           (8): IDR_DCRB(
#             (da_conv1): IDR_DDC(
#               (kernel): Sequential(
#                 (0): Linear(in_features=128, out_features=128, bias=False)
#                 (1): LeakyReLU(negative_slope=0.1, inplace=True)
#                 (2): Linear(in_features=128, out_features=1152, bias=False)
#               )
#             )
#             (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (relu): LeakyReLU(negative_slope=0.1, inplace=True)
#           )
#           (9): IDR_DCRB(
#             (da_conv1): IDR_DDC(
#               (kernel): Sequential(
#                 (0): Linear(in_features=128, out_features=128, bias=False)
#                 (1): LeakyReLU(negative_slope=0.1, inplace=True)
#                 (2): Linear(in_features=128, out_features=1152, bias=False)
#               )
#             )
#             (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (relu): LeakyReLU(negative_slope=0.1, inplace=True)
#           )
#           (10): IDR_DCRB(
#             (da_conv1): IDR_DDC(
#               (kernel): Sequential(
#                 (0): Linear(in_features=128, out_features=128, bias=False)
#                 (1): LeakyReLU(negative_slope=0.1, inplace=True)
#                 (2): Linear(in_features=128, out_features=1152, bias=False)
#               )
#             )
#             (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (relu): LeakyReLU(negative_slope=0.1, inplace=True)
#           )
#           (11): IDR_DCRB(
#             (da_conv1): IDR_DDC(
#               (kernel): Sequential(
#                 (0): Linear(in_features=128, out_features=128, bias=False)
#                 (1): LeakyReLU(negative_slope=0.1, inplace=True)
#                 (2): Linear(in_features=128, out_features=1152, bias=False)
#               )
#             )
#             (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (relu): LeakyReLU(negative_slope=0.1, inplace=True)
#           )
#           (12): IDR_DCRB(
#             (da_conv1): IDR_DDC(
#               (kernel): Sequential(
#                 (0): Linear(in_features=128, out_features=128, bias=False)
#                 (1): LeakyReLU(negative_slope=0.1, inplace=True)
#                 (2): Linear(in_features=128, out_features=1152, bias=False)
#               )
#             )
#             (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (relu): LeakyReLU(negative_slope=0.1, inplace=True)
#           )
#           (13): IDR_DCRB(
#             (da_conv1): IDR_DDC(
#               (kernel): Sequential(
#                 (0): Linear(in_features=128, out_features=128, bias=False)
#                 (1): LeakyReLU(negative_slope=0.1, inplace=True)
#                 (2): Linear(in_features=128, out_features=1152, bias=False)
#               )
#             )
#             (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (relu): LeakyReLU(negative_slope=0.1, inplace=True)
#           )
#           (14): IDR_DCRB(
#             (da_conv1): IDR_DDC(
#               (kernel): Sequential(
#                 (0): Linear(in_features=128, out_features=128, bias=False)
#                 (1): LeakyReLU(negative_slope=0.1, inplace=True)
#                 (2): Linear(in_features=128, out_features=1152, bias=False)
#               )
#             )
#             (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (relu): LeakyReLU(negative_slope=0.1, inplace=True)
#           )
#           (15): IDR_DCRB(
#             (da_conv1): IDR_DDC(
#               (kernel): Sequential(
#                 (0): Linear(in_features=128, out_features=128, bias=False)
#                 (1): LeakyReLU(negative_slope=0.1, inplace=True)
#                 (2): Linear(in_features=128, out_features=1152, bias=False)
#               )
#             )
#             (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (relu): LeakyReLU(negative_slope=0.1, inplace=True)
#           )
#           (16): IDR_DCRB(
#             (da_conv1): IDR_DDC(
#               (kernel): Sequential(
#                 (0): Linear(in_features=128, out_features=128, bias=False)
#                 (1): LeakyReLU(negative_slope=0.1, inplace=True)
#                 (2): Linear(in_features=128, out_features=1152, bias=False)
#               )
#             )
#             (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (relu): LeakyReLU(negative_slope=0.1, inplace=True)
#           )
#           (17): IDR_DCRB(
#             (da_conv1): IDR_DDC(
#               (kernel): Sequential(
#                 (0): Linear(in_features=128, out_features=128, bias=False)
#                 (1): LeakyReLU(negative_slope=0.1, inplace=True)
#                 (2): Linear(in_features=128, out_features=1152, bias=False)
#               )
#             )
#             (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (relu): LeakyReLU(negative_slope=0.1, inplace=True)
#           )
#           (18): IDR_DCRB(
#             (da_conv1): IDR_DDC(
#               (kernel): Sequential(
#                 (0): Linear(in_features=128, out_features=128, bias=False)
#                 (1): LeakyReLU(negative_slope=0.1, inplace=True)
#                 (2): Linear(in_features=128, out_features=1152, bias=False)
#               )
#             )
#             (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (relu): LeakyReLU(negative_slope=0.1, inplace=True)
#           )
#           (19): IDR_DCRB(
#             (da_conv1): IDR_DDC(
#               (kernel): Sequential(
#                 (0): Linear(in_features=128, out_features=128, bias=False)
#                 (1): LeakyReLU(negative_slope=0.1, inplace=True)
#                 (2): Linear(in_features=128, out_features=1152, bias=False)
#               )
#             )
#             (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (relu): LeakyReLU(negative_slope=0.1, inplace=True)
#           )
#           (20): IDR_DCRB(
#             (da_conv1): IDR_DDC(
#               (kernel): Sequential(
#                 (0): Linear(in_features=128, out_features=128, bias=False)
#                 (1): LeakyReLU(negative_slope=0.1, inplace=True)
#                 (2): Linear(in_features=128, out_features=1152, bias=False)
#               )
#             )
#             (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (relu): LeakyReLU(negative_slope=0.1, inplace=True)
#           )
#           (21): IDR_DCRB(
#             (da_conv1): IDR_DDC(
#               (kernel): Sequential(
#                 (0): Linear(in_features=128, out_features=128, bias=False)
#                 (1): LeakyReLU(negative_slope=0.1, inplace=True)
#                 (2): Linear(in_features=128, out_features=1152, bias=False)
#               )
#             )
#             (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (relu): LeakyReLU(negative_slope=0.1, inplace=True)
#           )
#           (22): IDR_DCRB(
#             (da_conv1): IDR_DDC(
#               (kernel): Sequential(
#                 (0): Linear(in_features=128, out_features=128, bias=False)
#                 (1): LeakyReLU(negative_slope=0.1, inplace=True)
#                 (2): Linear(in_features=128, out_features=1152, bias=False)
#               )
#             )
#             (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (relu): LeakyReLU(negative_slope=0.1, inplace=True)
#           )
#           (23): IDR_DCRB(
#             (da_conv1): IDR_DDC(
#               (kernel): Sequential(
#                 (0): Linear(in_features=128, out_features=128, bias=False)
#                 (1): LeakyReLU(negative_slope=0.1, inplace=True)
#                 (2): Linear(in_features=128, out_features=1152, bias=False)
#               )
#             )
#             (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (relu): LeakyReLU(negative_slope=0.1, inplace=True)
#           )
#           (24): IDR_DCRB(
#             (da_conv1): IDR_DDC(
#               (kernel): Sequential(
#                 (0): Linear(in_features=128, out_features=128, bias=False)
#                 (1): LeakyReLU(negative_slope=0.1, inplace=True)
#                 (2): Linear(in_features=128, out_features=1152, bias=False)
#               )
#             )
#             (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (relu): LeakyReLU(negative_slope=0.1, inplace=True)
#           )
#           (25): IDR_DCRB(
#             (da_conv1): IDR_DDC(
#               (kernel): Sequential(
#                 (0): Linear(in_features=128, out_features=128, bias=False)
#                 (1): LeakyReLU(negative_slope=0.1, inplace=True)
#                 (2): Linear(in_features=128, out_features=1152, bias=False)
#               )
#             )
#             (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (relu): LeakyReLU(negative_slope=0.1, inplace=True)
#           )
#           (26): IDR_DCRB(
#             (da_conv1): IDR_DDC(
#               (kernel): Sequential(
#                 (0): Linear(in_features=128, out_features=128, bias=False)
#                 (1): LeakyReLU(negative_slope=0.1, inplace=True)
#                 (2): Linear(in_features=128, out_features=1152, bias=False)
#               )
#             )
#             (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (relu): LeakyReLU(negative_slope=0.1, inplace=True)
#           )
#           (27): IDR_DCRB(
#             (da_conv1): IDR_DDC(
#               (kernel): Sequential(
#                 (0): Linear(in_features=128, out_features=128, bias=False)
#                 (1): LeakyReLU(negative_slope=0.1, inplace=True)
#                 (2): Linear(in_features=128, out_features=1152, bias=False)
#               )
#             )
#             (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (relu): LeakyReLU(negative_slope=0.1, inplace=True)
#           )
#           (28): IDR_DCRB(
#             (da_conv1): IDR_DDC(
#               (kernel): Sequential(
#                 (0): Linear(in_features=128, out_features=128, bias=False)
#                 (1): LeakyReLU(negative_slope=0.1, inplace=True)
#                 (2): Linear(in_features=128, out_features=1152, bias=False)
#               )
#             )
#             (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (relu): LeakyReLU(negative_slope=0.1, inplace=True)
#           )
#           (29): IDR_DCRB(
#             (da_conv1): IDR_DDC(
#               (kernel): Sequential(
#                 (0): Linear(in_features=128, out_features=128, bias=False)
#                 (1): LeakyReLU(negative_slope=0.1, inplace=True)
#                 (2): Linear(in_features=128, out_features=1152, bias=False)
#               )
#             )
#             (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (relu): LeakyReLU(negative_slope=0.1, inplace=True)
#           )
#           (30): IDR_DCRB(
#             (da_conv1): IDR_DDC(
#               (kernel): Sequential(
#                 (0): Linear(in_features=128, out_features=128, bias=False)
#                 (1): LeakyReLU(negative_slope=0.1, inplace=True)
#                 (2): Linear(in_features=128, out_features=1152, bias=False)
#               )
#             )
#             (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (relu): LeakyReLU(negative_slope=0.1, inplace=True)
#           )
#           (31): IDR_DCRB(
#             (da_conv1): IDR_DDC(
#               (kernel): Sequential(
#                 (0): Linear(in_features=128, out_features=128, bias=False)
#                 (1): LeakyReLU(negative_slope=0.1, inplace=True)
#                 (2): Linear(in_features=128, out_features=1152, bias=False)
#               )
#             )
#             (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (relu): LeakyReLU(negative_slope=0.1, inplace=True)
#           )
#           (32): IDR_DCRB(
#             (da_conv1): IDR_DDC(
#               (kernel): Sequential(
#                 (0): Linear(in_features=128, out_features=128, bias=False)
#                 (1): LeakyReLU(negative_slope=0.1, inplace=True)
#                 (2): Linear(in_features=128, out_features=1152, bias=False)
#               )
#             )
#             (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (relu): LeakyReLU(negative_slope=0.1, inplace=True)
#           )
#           (33): IDR_DCRB(
#             (da_conv1): IDR_DDC(
#               (kernel): Sequential(
#                 (0): Linear(in_features=128, out_features=128, bias=False)
#                 (1): LeakyReLU(negative_slope=0.1, inplace=True)
#                 (2): Linear(in_features=128, out_features=1152, bias=False)
#               )
#             )
#             (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (relu): LeakyReLU(negative_slope=0.1, inplace=True)
#           )
#           (34): IDR_DCRB(
#             (da_conv1): IDR_DDC(
#               (kernel): Sequential(
#                 (0): Linear(in_features=128, out_features=128, bias=False)
#                 (1): LeakyReLU(negative_slope=0.1, inplace=True)
#                 (2): Linear(in_features=128, out_features=1152, bias=False)
#               )
#             )
#             (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (relu): LeakyReLU(negative_slope=0.1, inplace=True)
#           )
#           (35): IDR_DCRB(
#             (da_conv1): IDR_DDC(
#               (kernel): Sequential(
#                 (0): Linear(in_features=128, out_features=128, bias=False)
#                 (1): LeakyReLU(negative_slope=0.1, inplace=True)
#                 (2): Linear(in_features=128, out_features=1152, bias=False)
#               )
#             )
#             (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (relu): LeakyReLU(negative_slope=0.1, inplace=True)
#           )
#           (36): IDR_DCRB(
#             (da_conv1): IDR_DDC(
#               (kernel): Sequential(
#                 (0): Linear(in_features=128, out_features=128, bias=False)
#                 (1): LeakyReLU(negative_slope=0.1, inplace=True)
#                 (2): Linear(in_features=128, out_features=1152, bias=False)
#               )
#             )
#             (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (relu): LeakyReLU(negative_slope=0.1, inplace=True)
#           )
#           (37): IDR_DCRB(
#             (da_conv1): IDR_DDC(
#               (kernel): Sequential(
#                 (0): Linear(in_features=128, out_features=128, bias=False)
#                 (1): LeakyReLU(negative_slope=0.1, inplace=True)
#                 (2): Linear(in_features=128, out_features=1152, bias=False)
#               )
#             )
#             (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (relu): LeakyReLU(negative_slope=0.1, inplace=True)
#           )
#           (38): IDR_DCRB(
#             (da_conv1): IDR_DDC(
#               (kernel): Sequential(
#                 (0): Linear(in_features=128, out_features=128, bias=False)
#                 (1): LeakyReLU(negative_slope=0.1, inplace=True)
#                 (2): Linear(in_features=128, out_features=1152, bias=False)
#               )
#             )
#             (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (relu): LeakyReLU(negative_slope=0.1, inplace=True)
#           )
#           (39): IDR_DCRB(
#             (da_conv1): IDR_DDC(
#               (kernel): Sequential(
#                 (0): Linear(in_features=128, out_features=128, bias=False)
#                 (1): LeakyReLU(negative_slope=0.1, inplace=True)
#                 (2): Linear(in_features=128, out_features=1152, bias=False)
#               )
#             )
#             (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (relu): LeakyReLU(negative_slope=0.1, inplace=True)
#           )
#           (40): IDR_DCRB(
#             (da_conv1): IDR_DDC(
#               (kernel): Sequential(
#                 (0): Linear(in_features=128, out_features=128, bias=False)
#                 (1): LeakyReLU(negative_slope=0.1, inplace=True)
#                 (2): Linear(in_features=128, out_features=1152, bias=False)
#               )
#             )
#             (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (relu): LeakyReLU(negative_slope=0.1, inplace=True)
#           )
#           (41): IDR_DCRB(
#             (da_conv1): IDR_DDC(
#               (kernel): Sequential(
#                 (0): Linear(in_features=128, out_features=128, bias=False)
#                 (1): LeakyReLU(negative_slope=0.1, inplace=True)
#                 (2): Linear(in_features=128, out_features=1152, bias=False)
#               )
#             )
#             (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (relu): LeakyReLU(negative_slope=0.1, inplace=True)
#           )
#         )
#       )
#       (1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#     (tail): Sequential(
#       (0): Upsampler(
#         (0): Conv2d(128, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): PixelShuffle(upscale_factor=2)
#         (2): Conv2d(128, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (3): PixelShuffle(upscale_factor=2)
#       )
#       (1): Conv2d(128, 3, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#   )
#   (E_st): KD_IDE(
#     (E): Sequential(
#       (0): Conv2d(3, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): LeakyReLU(negative_slope=0.1, inplace=True)
#       (2): ResBlock(
#         (body): Sequential(
#           (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): LeakyReLU(negative_slope=0.1, inplace=True)
#           (2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#       )
#       (3): ResBlock(
#         (body): Sequential(
#           (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): LeakyReLU(negative_slope=0.1, inplace=True)
#           (2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#       )
#       (4): ResBlock(
#         (body): Sequential(
#           (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): LeakyReLU(negative_slope=0.1, inplace=True)
#           (2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#       )
#       (5): ResBlock(
#         (body): Sequential(
#           (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): LeakyReLU(negative_slope=0.1, inplace=True)
#           (2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#       )
#       (6): ResBlock(
#         (body): Sequential(
#           (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): LeakyReLU(negative_slope=0.1, inplace=True)
#           (2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#       )
#       (7): ResBlock(
#         (body): Sequential(
#           (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): LeakyReLU(negative_slope=0.1, inplace=True)
#           (2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#       )
#       (8): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (9): LeakyReLU(negative_slope=0.1, inplace=True)
#       (10): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (11): LeakyReLU(negative_slope=0.1, inplace=True)
#       (12): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (13): LeakyReLU(negative_slope=0.1, inplace=True)
#       (14): AdaptiveAvgPool2d(output_size=1)
#     )
#     (mlp): Sequential(
#       (0): Linear(in_features=512, out_features=512, bias=True)
#       (1): LeakyReLU(negative_slope=0.1, inplace=True)
#       (2): Linear(in_features=512, out_features=512, bias=True)
#       (3): LeakyReLU(negative_slope=0.1, inplace=True)
#     )
#     (compress): Sequential(
#       (0): Linear(in_features=512, out_features=128, bias=True)
#       (1): LeakyReLU(negative_slope=0.1, inplace=True)
#     )
#   )
#   (pixel_unshuffle): PixelUnshuffle(downscale_factor=4)
# )
# 2024-02-03 08:14:08,484 INFO: Loading BlindSR_ST model from /content/gdrive/MyDrive/KDSR-GAN/experiments/debug_train_KDSRNetSTx4_1000k/models/net_g_8.pth, with param key: [params_ema].
# 2024-02-03 08:14:08,553 INFO: Loss [KDLoss] is created.
# 2024-02-03 08:14:08,554 INFO: Use Exponential Moving Average with decay: 0.999
# 2024-02-03 08:14:08,709 INFO: Network [BlindSR_ST] is created.
# 2024-02-03 08:14:08,983 INFO: Loading BlindSR_ST model from /content/gdrive/MyDrive/KDSR-GAN/experiments/debug_train_KDSRNetSTx4_1000k/models/net_g_8.pth, with param key: [params_ema].
# 2024-02-03 08:14:09,087 INFO: Network [UNetDiscriminatorSN] is created.
# 2024-02-03 08:14:09,093 INFO: Network: UNetDiscriminatorSN, with parameters: 4,376,897
# 2024-02-03 08:14:09,093 INFO: UNetDiscriminatorSN(
#   (conv0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv1): Conv2d(64, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   (conv2): Conv2d(128, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   (conv3): Conv2d(256, 512, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   (conv4): Conv2d(512, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (conv5): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (conv6): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (conv7): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (conv8): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (conv9): Conv2d(64, 1, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# )
# 2024-02-03 08:14:09,094 INFO: Loss [L1Loss] is created.
# Downloading: "https://download.pytorch.org/models/vgg19-dcbb9e9d.pth" to /root/.cache/torch/hub/checkpoints/vgg19-dcbb9e9d.pth
# 100% 548M/548M [00:06<00:00, 84.0MB/s]
# 2024-02-03 08:14:17,925 INFO: Loss [PerceptualLoss] is created.
# 2024-02-03 08:14:17,957 INFO: Loss [GANLoss] is created.
# 2024-02-03 08:14:18,312 INFO: Network [BlindSR_TA] is created.
# 2024-02-03 08:14:18,863 INFO: Loading BlindSR_TA model from /content/gdrive/MyDrive/KDSR-GAN/experiments/debug_train_KDSRNetTAx4plus_1000k_B12G4/models/net_g_8.pth, with param key: [params_ema].
# 2024-02-03 08:14:18,959 INFO: Model [KDSRGANSTModel] is created.
# 2024-02-03 08:14:19,119 INFO: Start training from epoch: 0, iter: 0
# 2024-02-03 08:16:57,852 INFO: End of training. Time consumed: 0:02:38
# 2024-02-03 08:16:57,852 INFO: Save the latest model.

# %%
from PIL import Image
import os

directory_path = '/content/gdrive/MyDrive/KDSR-GAN/datasets/test/DF2K_gt'

# List all files in the directory
image_files = [f for f in os.listdir(directory_path) if f.endswith(('.png', '.jpg', '.jpeg'))]

# Iterate over the image files and print their sizes
for image_file in image_files:
    image_path = os.path.join(directory_path, image_file)

    # Open the image with Pillow
    img = Image.open(image_path)

    # Print the image size
    print(f"Image: {image_file}, Size: {img.size}")
# Out:
# Image: 000400.png, Size: (2028, 1356)
# Image: 000401.png, Size: (2040, 1512)
# Image: 000402.png, Size: (2040, 1584)
# Image: 000403.png, Size: (2040, 1140)
# Image: 000404.png, Size: (1200, 1596)
# Image: 000405.png, Size: (2040, 1524)
# Image: 000406.png, Size: (2040, 1140)
# Image: 000407.png, Size: (2040, 1356)
# Image: 000409.png, Size: (2040, 1356)
# Image: 000408.png, Size: (2040, 1356)
# Image: 000410.png, Size: (2040, 1356)
# Image: 000412.png, Size: (2040, 1392)
# Image: 000413.png, Size: (1140, 2040)
# Image: 000411.png, Size: (2040, 1356)
# Image: 000414.png, Size: (2040, 1092)
# Image: 000415.png, Size: (2040, 1524)
# Image: 000416.png, Size: (1620, 1080)
# Image: 000418.png, Size: (1356, 2040)
# Image: 000417.png, Size: (2040, 1404)
# Image: 000420.png, Size: (1524, 2040)
# Image: 000419.png, Size: (1596, 888)
# Image: 000421.png, Size: (2040, 1356)
# Image: 000422.png, Size: (2040, 1524)
# Image: 000423.png, Size: (2040, 1524)
# Image: 000424.png, Size: (2040, 1356)
# Image: 000425.png, Size: (2040, 2004)
# Image: 000426.png, Size: (1356, 2028)
# Image: 000428.png, Size: (2040, 1356)
# Image: 000427.png, Size: (2040, 1356)
# Image: 000429.png, Size: (2040, 1356)
# Image: 000430.png, Size: (1356, 2040)
# Image: 000431.png, Size: (2040, 1356)
# Image: 000433.png, Size: (2040, 1356)
# Image: 000432.png, Size: (2040, 1320)
# Image: 000434.png, Size: (2040, 1524)
# Image: 000436.png, Size: (2040, 1356)
# Image: 000435.png, Size: (2040, 1356)
# Image: 000437.png, Size: (1356, 2040)
# Image: 000438.png, Size: (2040, 1344)
# Image: 000439.png, Size: (2040, 1356)
# Image: 000440.png, Size: (1164, 2040)
# Image: 000441.png, Size: (2040, 1524)
# Image: 000442.png, Size: (1992, 1332)
# Image: 000443.png, Size: (2040, 1656)
# Image: 000444.png, Size: (2040, 1356)
# Image: 000445.png, Size: (2040, 1356)
# Image: 000446.png, Size: (2040, 1344)
# Image: 000447.png, Size: (2040, 2040)
# Image: 000448.png, Size: (2040, 1524)
# Image: 000449.png, Size: (1632, 2040)
# Image: 000450.png, Size: (2040, 1392)
# Image: 000451.png, Size: (2040, 1356)

# %%
from PIL import Image
import os

directory_path = '/content/gdrive/MyDrive/KDSR-GAN/datasets/test/DF2K_lq'

# List all files in the directory
image_files = [f for f in os.listdir(directory_path) if f.endswith(('.png', '.jpg', '.jpeg'))]

# Iterate over the image files and print their sizes
for image_file in image_files:
    image_path = os.path.join(directory_path, image_file)

    # Open the image with Pillow
    img = Image.open(image_path)

    # Print the image size
    print(f"Image: {image_file}, Size: {img.size}")
# Out:
# Image: 000402.png, Size: (1020, 792)
# Image: 000400.png, Size: (1014, 678)
# Image: 000401.png, Size: (1020, 756)
# Image: 000406.png, Size: (1020, 570)
# Image: 000403.png, Size: (1020, 570)
# Image: 000410.png, Size: (1020, 678)
# Image: 000404.png, Size: (600, 798)
# Image: 000408.png, Size: (1020, 678)
# Image: 000409.png, Size: (1020, 678)
# Image: 000405.png, Size: (1020, 762)
# Image: 000407.png, Size: (1020, 678)
# Image: 000415.png, Size: (1020, 762)
# Image: 000414.png, Size: (1020, 546)
# Image: 000412.png, Size: (1020, 696)
# Image: 000417.png, Size: (1020, 702)
# Image: 000413.png, Size: (570, 1020)
# Image: 000411.png, Size: (1020, 678)
# Image: 000416.png, Size: (810, 540)
# Image: 000419.png, Size: (798, 444)
# Image: 000418.png, Size: (678, 1020)
# Image: 000420.png, Size: (762, 1020)
# Image: 000422.png, Size: (1020, 762)
# Image: 000423.png, Size: (1020, 762)
# Image: 000424.png, Size: (1020, 678)
# Image: 000421.png, Size: (1020, 678)
# Image: 000426.png, Size: (678, 1014)
# Image: 000429.png, Size: (1020, 678)
# Image: 000428.png, Size: (1020, 678)
# Image: 000427.png, Size: (1020, 678)
# Image: 000425.png, Size: (1020, 1002)
# Image: 000430.png, Size: (678, 1020)
# Image: 000432.png, Size: (1020, 660)
# Image: 000431.png, Size: (1020, 678)
# Image: 000433.png, Size: (1020, 678)
# Image: 000434.png, Size: (1020, 762)
# Image: 000437.png, Size: (678, 1020)
# Image: 000438.png, Size: (1020, 672)
# Image: 000436.png, Size: (1020, 678)
# Image: 000435.png, Size: (1020, 678)
# Image: 000439.png, Size: (1020, 678)
# Image: 000440.png, Size: (582, 1020)
# Image: 000442.png, Size: (996, 666)
# Image: 000441.png, Size: (1020, 762)
# Image: 000444.png, Size: (1020, 678)
# Image: 000443.png, Size: (1020, 828)
# Image: 000445.png, Size: (1020, 678)
# Image: 000446.png, Size: (1020, 672)
# Image: 000448.png, Size: (1020, 762)
# Image: 000447.png, Size: (1020, 1020)
# Image: 000449.png, Size: (816, 1020)
# Image: 000451.png, Size: (1020, 678)
# Image: 000450.png, Size: (1020, 696)

# %%
from PIL import Image
import os

# Directory path containing the images
directory_path = '/content/gdrive/MyDrive/KDSR-GAN/datasets/test/DF2K_gt'

# Output directory where resized images will be saved
output_directory = '/content/gdrive/MyDrive/KDSR-GAN/datasets/test/DF2K_gt_resized'

# Target size for resizing
target_size = (1020,678)  # Change this to your desired size

# Create the output directory if it doesn't exist
os.makedirs(output_directory, exist_ok=True)

# List all files in the directory
image_files = [f for f in os.listdir(directory_path) if f.endswith(('.png', '.jpg', '.jpeg'))]

# Iterate over the image files and resize
for image_file in image_files:
    image_path = os.path.join(directory_path, image_file)

    # Open the image with Pillow
    img = Image.open(image_path)

    # Resize the image
    resized_img = img.resize(target_size, Image.ANTIALIAS)

    # Save the resized image to the output directory
    output_path = os.path.join(output_directory, image_file)
    resized_img.save(output_path)

    print(f"Resized {image_file} to {target_size}")
# Out:
# <ipython-input-6-739278074199>:27: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
#   resized_img = img.resize(target_size, Image.ANTIALIAS)
# Resized 000400.png to (1020, 678)
# Resized 000401.png to (1020, 678)
# Resized 000402.png to (1020, 678)
# Resized 000403.png to (1020, 678)
# Resized 000404.png to (1020, 678)
# Resized 000405.png to (1020, 678)
# Resized 000406.png to (1020, 678)
# Resized 000407.png to (1020, 678)
# Resized 000409.png to (1020, 678)
# Resized 000408.png to (1020, 678)
# Resized 000410.png to (1020, 678)
# Resized 000412.png to (1020, 678)
# Resized 000413.png to (1020, 678)
# Resized 000411.png to (1020, 678)
# Resized 000414.png to (1020, 678)
# Resized 000415.png to (1020, 678)
# Resized 000416.png to (1020, 678)
# Resized 000418.png to (1020, 678)
# Resized 000417.png to (1020, 678)
# Resized 000420.png to (1020, 678)
# Resized 000419.png to (1020, 678)
# Resized 000421.png to (1020, 678)
# Resized 000422.png to (1020, 678)
# Resized 000423.png to (1020, 678)
# Resized 000424.png to (1020, 678)
# Resized 000425.png to (1020, 678)
# Resized 000426.png to (1020, 678)
# Resized 000428.png to (1020, 678)
# Resized 000427.png to (1020, 678)
# Resized 000429.png to (1020, 678)
# Resized 000430.png to (1020, 678)
# Resized 000431.png to (1020, 678)
# Resized 000433.png to (1020, 678)
# Resized 000432.png to (1020, 678)
# Resized 000434.png to (1020, 678)
# Resized 000436.png to (1020, 678)
# Resized 000435.png to (1020, 678)
# Resized 000437.png to (1020, 678)
# Resized 000438.png to (1020, 678)
# Resized 000439.png to (1020, 678)
# Resized 000440.png to (1020, 678)
# Resized 000441.png to (1020, 678)
# Resized 000442.png to (1020, 678)
# Resized 000443.png to (1020, 678)
# Resized 000444.png to (1020, 678)
# Resized 000445.png to (1020, 678)
# Resized 000446.png to (1020, 678)
# Resized 000447.png to (1020, 678)
# Resized 000448.png to (1020, 678)
# Resized 000449.png to (1020, 678)
# Resized 000450.png to (1020, 678)
# Resized 000451.png to (1020, 678)

# %%
from PIL import Image
import os

# Directory path containing the images
directory_path = '/content/gdrive/MyDrive/KDSR-GAN/datasets/test/DF2K_lq'

# Output directory where resized images will be saved
output_directory = '/content/gdrive/MyDrive/KDSR-GAN/datasets/test/DF2K_lq_resized'

# Target size for resizing
target_size = (1020, 678)  # Change this to your desired size

# Create the output directory if it doesn't exist
os.makedirs(output_directory, exist_ok=True)

# List all files in the directory
image_files = [f for f in os.listdir(directory_path) if f.endswith(('.png', '.jpg', '.jpeg'))]

# Iterate over the image files and resize or copy
for image_file in image_files:
    image_path = os.path.join(directory_path, image_file)

    # Open the image with Pillow
    img = Image.open(image_path)

    # Check if the image needs resizing
    if img.size != target_size:
        # Resize the image
        img = img.resize(target_size, Image.ANTIALIAS)

        # Save the resized image to the output directory
        output_path = os.path.join(output_directory, image_file)
        img.save(output_path)
        print(f"Resized {image_file} to {target_size}")
    else:
        # Copy the original image to the output directory
        output_path = os.path.join(output_directory, image_file)
        img.save(output_path)
        print(f"Copied original {image_file}")
# Out:
# <ipython-input-13-5d233fda156a>:29: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
#   img = img.resize(target_size, Image.ANTIALIAS)
# Resized 000402.png to (1020, 678)
# Resized 000400.png to (1020, 678)
# Resized 000401.png to (1020, 678)
# Resized 000406.png to (1020, 678)
# Resized 000403.png to (1020, 678)
# Copied original 000410.png
# Resized 000404.png to (1020, 678)
# Copied original 000408.png
# Copied original 000409.png
# Resized 000405.png to (1020, 678)
# Copied original 000407.png
# Resized 000415.png to (1020, 678)
# Resized 000414.png to (1020, 678)
# Resized 000412.png to (1020, 678)
# Resized 000417.png to (1020, 678)
# Resized 000413.png to (1020, 678)
# Copied original 000411.png
# Resized 000416.png to (1020, 678)
# Resized 000419.png to (1020, 678)
# Resized 000418.png to (1020, 678)
# Resized 000420.png to (1020, 678)
# Resized 000422.png to (1020, 678)
# Resized 000423.png to (1020, 678)
# Copied original 000424.png
# Copied original 000421.png
# Resized 000426.png to (1020, 678)
# Copied original 000429.png
# Copied original 000428.png
# Copied original 000427.png
# Resized 000425.png to (1020, 678)
# Resized 000430.png to (1020, 678)
# Resized 000432.png to (1020, 678)
# Copied original 000431.png
# Copied original 000433.png
# Resized 000434.png to (1020, 678)
# Resized 000437.png to (1020, 678)
# Resized 000438.png to (1020, 678)
# Copied original 000436.png
# Copied original 000435.png
# Copied original 000439.png
# Resized 000440.png to (1020, 678)
# Resized 000442.png to (1020, 678)
# Resized 000441.png to (1020, 678)
# Copied original 000444.png
# Resized 000443.png to (1020, 678)
# Copied original 000445.png
# Resized 000446.png to (1020, 678)
# Resized 000448.png to (1020, 678)
# Resized 000447.png to (1020, 678)
# Resized 000449.png to (1020, 678)
# Copied original 000451.png
# Resized 000450.png to (1020, 678)

# %%
import glob

# Directory path containing the images
directory_path = '/content/gdrive/MyDrive/KDSR-GAN/datasets/test/DF2K_gt'

# Define the image file extensions you want to consider
image_extensions = ['png', 'jpg', 'jpeg']

# Create a glob pattern to match image files
pattern = f"{directory_path}/*.*"
image_files = [file for file in glob.glob(pattern) if file.lower().split('.')[-1] in image_extensions]

# Get the number of images
num_images = len(image_files)

# Print the number of images
print(f"Number of Images: {num_images}")
# Out:
# Number of Images: 52

# %%
import glob

# Directory path containing the images
directory_path = '/content/gdrive/MyDrive/KDSR-GAN/datasets/test/DF2K_lq'

# Define the image file extensions you want to consider
image_extensions = ['png', 'jpg', 'jpeg']

# Create a glob pattern to match image files
pattern = f"{directory_path}/*.*"
image_files = [file for file in glob.glob(pattern) if file.lower().split('.')[-1] in image_extensions]

# Get the number of images
num_images = len(image_files)

# Print the number of images
print(f"Number of Images: {num_images}")
# Out:
# Number of Images: 52
